# %%
from PyPDF2 import PdfReader
from langchain_core.documents import Document
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain_groq import ChatGroq
from py2neo import Graph

# Initialize the LLM model
GROQ_API_KEY = ""
llm = ChatGroq(
    groq_api_key=GROQ_API_KEY, 
    model_name="Gemma2-9b-It",
    temperature=0.7,          # Controls the randomness of the output
    max_tokens=8000,            # Maximum number of tokens in the response
    stop=["\n\n"],             # A list of tokens where the generation will stop
    model_kwargs={
        "top_p": 0.9,                 # Controls diversity via nucleus sampling
        "frequency_penalty": 0.0,     # Reduces repetition of words/phrases
        "presence_penalty": 0.0       # Increases the likelihood of introducing new topics
    }
)

# %%
def pdf_to_text_chunks(pdf_path, chunk_size=1000):
    reader = PdfReader(pdf_path)
    full_text = ""

    # Extract text from each page
    for page in reader.pages:
        full_text += page.extract_text() or ""

    # Split the text into chunks of the specified size
    chunks = [full_text[i:i + chunk_size] for i in range(0, len(full_text), chunk_size)]
    return chunks

# Provide your PDF file path
pdf_path = "Rajaji-Mahabharata.pdf"
chunks = pdf_to_text_chunks(pdf_path)

# %%
# Convert chunks into LangChain documents
documents = [Document(page_content=chunk) for chunk in chunks]

# %%
print(type(documents))

# %%
import os

# Set folder name where graph documents will be stored
output_folder = "df"

# Create the folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

llm_transformer = LLMGraphTransformer(llm=llm)
graph_documents = []

for idx, document in enumerate(documents):
    try:
        graph_doc = llm_transformer.convert_to_graph_documents([document])
        graph_documents.extend(graph_doc)
        
        # Save each graph document as a file
        graph_file = os.path.join(output_folder, f"graph_document_{idx}.txt")
        with open(graph_file, 'w') as f:
            f.write(str(graph_doc))
        
        print(f"Graph document {idx} successfully created and saved.")
    
    except Exception as e:
        print(f"Error processing document: {document.page_content[:50]}... - Skipping. Error: {e}")
# Out:
# Graph document 0 successfully created and saved.
# Graph document 1 successfully created and saved.
# Graph document 2 successfully created and saved.
# Graph document 3 successfully created and saved.
# Graph document 4 successfully created and saved.
# Graph document 5 successfully created and saved.
# Graph document 6 successfully created and saved.
# Graph document 7 successfully created and saved.
# Graph document 8 successfully created and saved.
# Graph document 9 successfully created and saved.
# Graph document 10 successfully created and saved.
# Graph document 11 successfully created and saved.
# Graph document 12 successfully created and saved.
# Graph document 13 successfully created and saved.
# Graph document 14 successfully created and saved.
# Graph document 15 successfully created and saved.
# Graph document 16 successfully created and saved.
# Graph document 17 successfully created and saved.
# Graph document 18 successfully created and saved.
# Graph document 19 successfully created and saved.
# Graph document 20 successfully created and saved.
# Graph document 21 successfully created and saved.
# Graph document 22 successfully created and saved.
# Graph document 23 successfully created and saved.
# Graph document 24 successfully created and saved.
# Graph document 25 successfully created and saved.
# Graph document 26 successfully created and saved.
# Graph document 27 successfully created and saved.
# Graph document 28 successfully created and saved.
# Graph document 29 successfully created and saved.
# Graph document 30 successfully created and saved.
# Graph document 31 successfully created and saved.
# Graph document 32 successfully created and saved.
# Graph document 33 successfully created and saved.
# Graph document 34 successfully created and saved.
# Graph document 35 successfully created and saved.
# Graph document 36 successfully created and saved.
# Graph document 37 successfully created and saved.
# Graph document 38 successfully created and saved.
# Graph document 39 successfully created and saved.
# Graph document 40 successfully created and saved.
# Graph document 41 successfully created and saved.
# Graph document 42 successfully created and saved.
# Graph document 43 successfully created and saved.
# Graph document 44 successfully created and saved.
# Graph document 45 successfully created and saved.
# Graph document 46 successfully created and saved.
# Graph document 47 successfully created and saved.
# Graph document 48 successfully created and saved.
# Graph document 49 successfully created and saved.
# Graph document 50 successfully created and saved.
# Graph document 51 successfully created and saved.
# Graph document 52 successfully created and saved.
# Graph document 53 successfully created and saved.
# Graph document 54 successfully created and saved.
# Graph document 55 successfully created and saved.
# Graph document 56 successfully created and saved.
# Graph document 57 successfully created and saved.
# Graph document 58 successfully created and saved.
# Graph document 59 successfully created and saved.
# Graph document 60 successfully created and saved.
# Graph document 61 successfully created and saved.
# Graph document 62 successfully created and saved.
# Graph document 63 successfully created and saved.
# Graph document 64 successfully created and saved.
# Graph document 65 successfully created and saved.
# Graph document 66 successfully created and saved.
# Graph document 67 successfully created and saved.
# Graph document 68 successfully created and saved.
# Graph document 69 successfully created and saved.
# Graph document 70 successfully created and saved.
# Graph document 71 successfully created and saved.
# Graph document 72 successfully created and saved.
# Graph document 73 successfully created and saved.
# Graph document 74 successfully created and saved.
# Graph document 75 successfully created and saved.
# Graph document 76 successfully created and saved.
# Graph document 77 successfully created and saved.
# Graph document 78 successfully created and saved.
# Graph document 79 successfully created and saved.
# Graph document 80 successfully created and saved.
# Graph document 81 successfully created and saved.
# Graph document 82 successfully created and saved.
# Graph document 83 successfully created and saved.
# Graph document 84 successfully created and saved.
# Graph document 85 successfully created and saved.
# Graph document 86 successfully created and saved.
# Graph document 87 successfully created and saved.
# Graph document 88 successfully created and saved.
# Graph document 89 successfully created and saved.
# Graph document 90 successfully created and saved.
# Graph document 91 successfully created and saved.
# Graph document 92 successfully created and saved.
# Graph document 93 successfully created and saved.
# Graph document 94 successfully created and saved.
# Graph document 95 successfully created and saved.
# Graph document 96 successfully created and saved.
# Graph document 97 successfully created and saved.
# Graph document 98 successfully created and saved.
# Graph document 99 successfully created and saved.
# Graph document 100 successfully created and saved.
# Graph document 101 successfully created and saved.
# Graph document 102 successfully created and saved.
# Graph document 103 successfully created and saved.
# Graph document 104 successfully created and saved.
# Graph document 105 successfully created and saved.
# Graph document 106 successfully created and saved.
# Graph document 107 successfully created and saved.
# Graph document 108 successfully created and saved.
# Graph document 109 successfully created and saved.
# Graph document 110 successfully created and saved.
# Graph document 111 successfully created and saved.
# Graph document 112 successfully created and saved.
# Graph document 113 successfully created and saved.
# Graph document 114 successfully created and saved.
# Graph document 115 successfully created and saved.
# Graph document 116 successfully created and saved.
# Graph document 117 successfully created and saved.
# Graph document 118 successfully created and saved.
# Graph document 119 successfully created and saved.
# Graph document 120 successfully created and saved.
# Graph document 121 successfully created and saved.
# Graph document 122 successfully created and saved.
# Graph document 123 successfully created and saved.
# Graph document 124 successfully created and saved.
# Graph document 125 successfully created and saved.
# Graph document 126 successfully created and saved.
# Graph document 127 successfully created and saved.
# Graph document 128 successfully created and saved.
# Graph document 129 successfully created and saved.
# Graph document 130 successfully created and saved.
# Graph document 131 successfully created and saved.
# Graph document 132 successfully created and saved.
# Graph document 133 successfully created and saved.
# Graph document 134 successfully created and saved.
# Graph document 135 successfully created and saved.
# Graph document 136 successfully created and saved.
# Graph document 137 successfully created and saved.
# Graph document 138 successfully created and saved.
# Graph document 139 successfully created and saved.
# Graph document 140 successfully created and saved.
# Graph document 141 successfully created and saved.
# Graph document 142 successfully created and saved.
# Graph document 143 successfully created and saved.
# Graph document 144 successfully created and saved.
# Graph document 145 successfully created and saved.
# Graph document 146 successfully created and saved.
# Graph document 147 successfully created and saved.
# Graph document 148 successfully created and saved.
# Graph document 149 successfully created and saved.
# Graph document 150 successfully created and saved.
# Graph document 151 successfully created and saved.
# Graph document 152 successfully created and saved.
# Graph document 153 successfully created and saved.
# Graph document 154 successfully created and saved.
# Graph document 155 successfully created and saved.
# Graph document 156 successfully created and saved.
# Graph document 157 successfully created and saved.
# Graph document 158 successfully created and saved.
# Graph document 159 successfully created and saved.
# Graph document 160 successfully created and saved.
# Graph document 161 successfully created and saved.
# Graph document 162 successfully created and saved.
# Graph document 163 successfully created and saved.
# Graph document 164 successfully created and saved.
# Graph document 165 successfully created and saved.
# Graph document 166 successfully created and saved.
# Graph document 167 successfully created and saved.
# Graph document 168 successfully created and saved.
# Graph document 169 successfully created and saved.
# Graph document 170 successfully created and saved.
# Graph document 171 successfully created and saved.
# Graph document 172 successfully created and saved.
# Graph document 173 successfully created and saved.
# Graph document 174 successfully created and saved.
# Graph document 175 successfully created and saved.
# Graph document 176 successfully created and saved.
# Graph document 177 successfully created and saved.
# Graph document 178 successfully created and saved.
# Graph document 179 successfully created and saved.
# Graph document 180 successfully created and saved.
# Graph document 181 successfully created and saved.
# Graph document 182 successfully created and saved.
# Graph document 183 successfully created and saved.
# Graph document 184 successfully created and saved.
# Graph document 185 successfully created and saved.
# Graph document 186 successfully created and saved.
# Graph document 187 successfully created and saved.
# Graph document 188 successfully created and saved.
# Graph document 189 successfully created and saved.
# Graph document 190 successfully created and saved.
# Graph document 191 successfully created and saved.
# Graph document 192 successfully created and saved.
# Graph document 193 successfully created and saved.
# Graph document 194 successfully created and saved.
# Graph document 195 successfully created and saved.
# Graph document 196 successfully created and saved.
# Graph document 197 successfully created and saved.
# Graph document 198 successfully created and saved.
# Graph document 199 successfully created and saved.
# Graph document 200 successfully created and saved.
# Graph document 201 successfully created and saved.
# Graph document 202 successfully created and saved.
# Graph document 203 successfully created and saved.
# Graph document 204 successfully created and saved.
# Graph document 205 successfully created and saved.
# Graph document 206 successfully created and saved.
# Graph document 207 successfully created and saved.
# Graph document 208 successfully created and saved.
# Graph document 209 successfully created and saved.
# Graph document 210 successfully created and saved.
# Graph document 211 successfully created and saved.
# Graph document 212 successfully created and saved.
# Graph document 213 successfully created and saved.
# Graph document 214 successfully created and saved.
# Graph document 215 successfully created and saved.
# Graph document 216 successfully created and saved.
# Graph document 217 successfully created and saved.
# Graph document 218 successfully created and saved.
# Graph document 219 successfully created and saved.
# Graph document 220 successfully created and saved.
# Graph document 221 successfully created and saved.
# Graph document 222 successfully created and saved.
# Graph document 223 successfully created and saved.
# Graph document 224 successfully created and saved.
# Graph document 225 successfully created and saved.
# Graph document 226 successfully created and saved.
# Graph document 227 successfully created and saved.
# Graph document 228 successfully created and saved.
# Graph document 229 successfully created and saved.
# Graph document 230 successfully created and saved.
# Graph document 231 successfully created and saved.
# Graph document 232 successfully created and saved.
# Graph document 233 successfully created and saved.
# Graph document 234 successfully created and saved.
# Graph document 235 successfully created and saved.
# Graph document 236 successfully created and saved.
# Graph document 237 successfully created and saved.
# Graph document 238 successfully created and saved.
# Graph document 239 successfully created and saved.
# Graph document 240 successfully created and saved.
# Graph document 241 successfully created and saved.
# Graph document 242 successfully created and saved.
# Graph document 243 successfully created and saved.
# Graph document 244 successfully created and saved.
# Graph document 245 successfully created and saved.
# Graph document 246 successfully created and saved.
# Graph document 247 successfully created and saved.
# Graph document 248 successfully created and saved.
# Graph document 249 successfully created and saved.
# Graph document 250 successfully created and saved.
# Graph document 251 successfully created and saved.
# Graph document 252 successfully created and saved.
# Graph document 253 successfully created and saved.
# Graph document 254 successfully created and saved.
# Graph document 255 successfully created and saved.
# Graph document 256 successfully created and saved.
# Graph document 257 successfully created and saved.
# Graph document 258 successfully created and saved.
# Graph document 259 successfully created and saved.
# Graph document 260 successfully created and saved.
# Graph document 261 successfully created and saved.
# Graph document 262 successfully created and saved.
# Graph document 263 successfully created and saved.
# Graph document 264 successfully created and saved.
# Graph document 265 successfully created and saved.
# Graph document 266 successfully created and saved.
# Graph document 267 successfully created and saved.
# Graph document 268 successfully created and saved.
# Graph document 269 successfully created and saved.
# Graph document 270 successfully created and saved.
# Graph document 271 successfully created and saved.
# Graph document 272 successfully created and saved.
# Graph document 273 successfully created and saved.
# Graph document 274 successfully created and saved.
# Graph document 275 successfully created and saved.
# Graph document 276 successfully created and saved.
# Graph document 277 successfully created and saved.
# Graph document 278 successfully created and saved.
# Graph document 279 successfully created and saved.
# Graph document 280 successfully created and saved.
# Graph document 281 successfully created and saved.
# Graph document 282 successfully created and saved.
# Graph document 283 successfully created and saved.
# Graph document 284 successfully created and saved.
# Graph document 285 successfully created and saved.
# Graph document 286 successfully created and saved.
# Graph document 287 successfully created and saved.
# Graph document 288 successfully created and saved.
# Graph document 289 successfully created and saved.
# Graph document 290 successfully created and saved.
# Graph document 291 successfully created and saved.
# Graph document 292 successfully created and saved.
# Graph document 293 successfully created and saved.
# Graph document 294 successfully created and saved.
# Graph document 295 successfully created and saved.
# Graph document 296 successfully created and saved.
# Graph document 297 successfully created and saved.
# Graph document 298 successfully created and saved.
# Graph document 299 successfully created and saved.
# Graph document 300 successfully created and saved.
# Graph document 301 successfully created and saved.
# Graph document 302 successfully created and saved.
# Graph document 303 successfully created and saved.
# Graph document 304 successfully created and saved.
# Graph document 305 successfully created and saved.
# Graph document 306 successfully created and saved.
# Graph document 307 successfully created and saved.
# Graph document 308 successfully created and saved.
# Graph document 309 successfully created and saved.
# Graph document 310 successfully created and saved.
# Graph document 311 successfully created and saved.
# Graph document 312 successfully created and saved.
# Graph document 313 successfully created and saved.
# Graph document 314 successfully created and saved.
# Graph document 315 successfully created and saved.
# Graph document 316 successfully created and saved.
# Graph document 317 successfully created and saved.
# Graph document 318 successfully created and saved.
# Graph document 319 successfully created and saved.
# Graph document 320 successfully created and saved.
# Graph document 321 successfully created and saved.
# Graph document 322 successfully created and saved.
# Graph document 323 successfully created and saved.
# Graph document 324 successfully created and saved.
# Graph document 325 successfully created and saved.
# Graph document 326 successfully created and saved.
# Graph document 327 successfully created and saved.
# Graph document 328 successfully created and saved.
# Graph document 329 successfully created and saved.
# Graph document 330 successfully created and saved.
# Graph document 331 successfully created and saved.
# Graph document 332 successfully created and saved.
# Graph document 333 successfully created and saved.
# Graph document 334 successfully created and saved.
# Graph document 335 successfully created and saved.
# Graph document 336 successfully created and saved.
# Graph document 337 successfully created and saved.
# Graph document 338 successfully created and saved.
# Graph document 339 successfully created and saved.
# Graph document 340 successfully created and saved.
# Graph document 341 successfully created and saved.
# Graph document 342 successfully created and saved.
# Graph document 343 successfully created and saved.
# Graph document 344 successfully created and saved.
# Graph document 345 successfully created and saved.
# Graph document 346 successfully created and saved.
# Graph document 347 successfully created and saved.
# Graph document 348 successfully created and saved.
# Graph document 349 successfully created and saved.
# Graph document 350 successfully created and saved.
# Graph document 351 successfully created and saved.
# Graph document 352 successfully created and saved.
# Graph document 353 successfully created and saved.
# Graph document 354 successfully created and saved.
# Graph document 355 successfully created and saved.
# Graph document 356 successfully created and saved.
# Graph document 357 successfully created and saved.
# Graph document 358 successfully created and saved.
# Graph document 359 successfully created and saved.
# Graph document 360 successfully created and saved.
# Graph document 361 successfully created and saved.
# Graph document 362 successfully created and saved.
# Graph document 363 successfully created and saved.
# Graph document 364 successfully created and saved.
# Graph document 365 successfully created and saved.
# Graph document 366 successfully created and saved.
# Graph document 367 successfully created and saved.
# Graph document 368 successfully created and saved.
# Graph document 369 successfully created and saved.
# Graph document 370 successfully created and saved.
# Graph document 371 successfully created and saved.
# Graph document 372 successfully created and saved.
# Graph document 373 successfully created and saved.
# Graph document 374 successfully created and saved.
# Graph document 375 successfully created and saved.
# Graph document 376 successfully created and saved.
# Graph document 377 successfully created and saved.
# Graph document 378 successfully created and saved.
# Graph document 379 successfully created and saved.
# Graph document 380 successfully created and saved.
# Graph document 381 successfully created and saved.
# Graph document 382 successfully created and saved.
# Graph document 383 successfully created and saved.
# Graph document 384 successfully created and saved.
# Graph document 385 successfully created and saved.
# Graph document 386 successfully created and saved.
# Graph document 387 successfully created and saved.
# Graph document 388 successfully created and saved.
# Graph document 389 successfully created and saved.
# Graph document 390 successfully created and saved.
# Graph document 391 successfully created and saved.
# Graph document 392 successfully created and saved.
# Graph document 393 successfully created and saved.
# Graph document 394 successfully created and saved.
# Graph document 395 successfully created and saved.
# Graph document 396 successfully created and saved.
# Graph document 397 successfully created and saved.
# Graph document 398 successfully created and saved.
# Graph document 399 successfully created and saved.
# Graph document 400 successfully created and saved.
# Graph document 401 successfully created and saved.
# Graph document 402 successfully created and saved.
# Graph document 403 successfully created and saved.
# Graph document 404 successfully created and saved.
# Graph document 405 successfully created and saved.
# Graph document 406 successfully created and saved.
# Graph document 407 successfully created and saved.
# Graph document 408 successfully created and saved.
# Graph document 409 successfully created and saved.
# Graph document 410 successfully created and saved.
# Graph document 411 successfully created and saved.
# Graph document 412 successfully created and saved.
# Graph document 413 successfully created and saved.
# Graph document 414 successfully created and saved.
# Graph document 415 successfully created and saved.
# Graph document 416 successfully created and saved.
# Graph document 417 successfully created and saved.
# Graph document 418 successfully created and saved.
# Graph document 419 successfully created and saved.
# Graph document 420 successfully created and saved.
# Graph document 421 successfully created and saved.
# Graph document 422 successfully created and saved.
# Graph document 423 successfully created and saved.
# Graph document 424 successfully created and saved.
# Graph document 425 successfully created and saved.
# Graph document 426 successfully created and saved.
# Graph document 427 successfully created and saved.
# Graph document 428 successfully created and saved.
# Graph document 429 successfully created and saved.
# Graph document 430 successfully created and saved.
# Graph document 431 successfully created and saved.
# Error processing document:  mere conceit
# and self -interest. Yet others may ... - Skipping. Error: Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "DynamicGraph"\n\t\t},\n\t\t"parameters": {\n\t\t\t"nodes": [\n\t\t\t\t{\n\t\t\t\t\t"id": "Balarama",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Rukma",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Bhishma",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Duryodhana",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Karna",\n\t\t\t\t\t"type": "person"\n\t\t\t\t}\n\t\t\t],\n\t\t\t"relationships": [\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Balarama",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "neutral_in_war"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Rukma",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "abstained_from_war"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Bhishma",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": "Duryodhana",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\t\t"type": "advising"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Bhishma",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": "Karna",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\t\t"type": "evaluation"\n\t\t\t\t}\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Graph document 433 successfully created and saved.
# Graph document 434 successfully created and saved.
# Graph document 435 successfully created and saved.
# Graph document 436 successfully created and saved.
# Graph document 437 successfully created and saved.
# Graph document 438 successfully created and saved.
# Graph document 439 successfully created and saved.
# Graph document 440 successfully created and saved.
# Graph document 441 successfully created and saved.
# Graph document 442 successfully created and saved.
# Graph document 443 successfully created and saved.
# Graph document 444 successfully created and saved.
# Graph document 445 successfully created and saved.
# Graph document 446 successfully created and saved.
# Graph document 447 successfully created and saved.
# Graph document 448 successfully created and saved.
# Graph document 449 successfully created and saved.
# Graph document 450 successfully created and saved.
# Graph document 451 successfully created and saved.
# Graph document 452 successfully created and saved.
# Graph document 453 successfully created and saved.
# Graph document 454 successfully created and saved.
# Graph document 455 successfully created and saved.
# Graph document 456 successfully created and saved.
# Error processing document: ous evening.
# 66. THE THIRD DAY'S BATTLE
# ON the... - Skipping. Error: Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "DynamicGraph"\n\t\t},\n\t\t"parameters": {\n\t\t\t"nodes": [\n\t\t\t\t{\n\t\t\t\t\t"id": "Bhishma",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Duryodhana",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Dhananjaya",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Dhrishtadyumna",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Bhima",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Arjuna",\n\t\t\t\t\t"type": "person"\n\t\t\t\t}\n\t\t\t],\n\t\t\t"relationships": [\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Bhishma",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "led"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Duryodhana",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "protected"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Dhananjaya",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "decided"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Dhrishtadyumna",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "decided"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Bhima",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "stood"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Arjuna",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "led"\n\t\t\t\t}\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>\n'}}
# Graph document 458 successfully created and saved.
# Graph document 459 successfully created and saved.
# Graph document 460 successfully created and saved.
# Graph document 461 successfully created and saved.
# Graph document 462 successfully created and saved.
# Graph document 463 successfully created and saved.
# Graph document 464 successfully created and saved.
# Graph document 465 successfully created and saved.
# Graph document 466 successfully created and saved.
# Graph document 467 successfully created and saved.
# Graph document 468 successfully created and saved.
# Graph document 469 successfully created and saved.
# Graph document 470 successfully created and saved.
# Graph document 471 successfully created and saved.
# Graph document 472 successfully created and saved.
# Graph document 473 successfully created and saved.
# Graph document 474 successfully created and saved.
# Error processing document: he sun went down and
# Bhishma gave orders to cease... - Skipping. Error: Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "DynamicGraph"\n\t\t},\n\t\t"parameters": {\n\t\t\t"nodes": [\n\t\t\t\t{\n\t\t\t\t\t"id": "Arjuna",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Bhishma",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Dhrishtadyumna",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Yudhishthira",\n\t\t\t\t\t"type": "person"\n\t\t\t\t}\n\t\t\t],\n\t\t\t"relationships": [\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Bhishma",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "gave_orders"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Arjuna",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "greeted"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Dhrishtadyumna",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "arrayed"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Yudhishthira",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "ordered"\n\t\t\t\t}\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Graph document 476 successfully created and saved.
# Graph document 477 successfully created and saved.
# Graph document 478 successfully created and saved.
# Graph document 479 successfully created and saved.
# Graph document 480 successfully created and saved.
# Graph document 481 successfully created and saved.
# Graph document 482 successfully created and saved.
# Graph document 483 successfully created and saved.
# Graph document 484 successfully created and saved.
# Graph document 485 successfully created and saved.
# Graph document 486 successfully created and saved.
# Error processing document: h day dawned, Bhishma
# arrayed his army in tortois... - Skipping. Error: Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "DynamicGraph"\n\t\t},\n\t\t"parameters": {\n\t\t\t"nodes": [\n\t\t\t\t{\n\t\t\t\t\t"id": "Bhishma",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Yudhishthira",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Dhrishtadyumna",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Bhima",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Satyaki",\n\t\t\t\t\t"type": "person"\n\t\t\t\t}\n\t\t\t],\n\t\t\t"relationships": [\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Bhishma",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "led_army"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Yudhishthira",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": "Dhrishtadyumna",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\t\t"type": "commanded"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Dhrishtadyumna",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "planned_strategy"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Bhima",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "led_prong"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Satyaki",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "led_prong"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Yudhishthira",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "led_prong"\n\t\t\t\t}\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Graph document 488 successfully created and saved.
# Graph document 489 successfully created and saved.
# Graph document 490 successfully created and saved.
# Graph document 491 successfully created and saved.
# Graph document 492 successfully created and saved.
# Graph document 493 successfully created and saved.
# Graph document 494 successfully created and saved.
# Graph document 495 successfully created and saved.
# Graph document 496 successfully created and saved.
# Graph document 497 successfully created and saved.
# Graph document 498 successfully created and saved.
# Graph document 499 successfully created and saved.
# Graph document 500 successfully created and saved.
# Graph document 501 successfully created and saved.
# Graph document 502 successfully created and saved.
# Graph document 503 successfully created and saved.
# Graph document 504 successfully created and saved.
# Graph document 505 successfully created and saved.
# Graph document 506 successfully created and saved.
# Graph document 507 successfully created and saved.
# Graph document 508 successfully created and saved.
# Graph document 509 successfully created and saved.
# Graph document 510 successfully created and saved.
# Graph document 511 successfully created and saved.
# Graph document 512 successfully created and saved.
# Graph document 513 successfully created and saved.
# Graph document 514 successfully created and saved.
# Graph document 515 successfully created and saved.
# Graph document 516 successfully created and saved.
# Graph document 517 successfully created and saved.
# Graph document 518 successfully created and saved.
# Graph document 519 successfully created and saved.
# Graph document 520 successfully created and saved.
# Graph document 521 successfully created and saved.
# Graph document 522 successfully created and saved.
# Graph document 523 successfully created and saved.
# Graph document 524 successfully created and saved.
# Graph document 525 successfully created and saved.
# Graph document 526 successfully created and saved.
# Graph document 527 successfully created and saved.
# Graph document 528 successfully created and saved.
# Graph document 529 successfully created and saved.
# Graph document 530 successfully created and saved.
# Graph document 531 successfully created and saved.
# Graph document 532 successfully created and saved.
# Graph document 533 successfully created and saved.
# Graph document 534 successfully created and saved.
# Graph document 535 successfully created and saved.
# Graph document 536 successfully created and saved.
# Graph document 537 successfully created and saved.
# Graph document 538 successfully created and saved.
# Graph document 539 successfully created and saved.
# Graph document 540 successfully created and saved.
# Graph document 541 successfully created and saved.
# Graph document 542 successfully created and saved.
# Graph document 543 successfully created and saved.
# Graph document 544 successfully created and saved.
# Graph document 545 successfully created and saved.
# Graph document 546 successfully created and saved.
# Graph document 547 successfully created and saved.
# Graph document 548 successfully created and saved.
# Graph document 549 successfully created and saved.
# Graph document 550 successfully created and saved.
# Graph document 551 successfully created and saved.
# Graph document 552 successfully created and saved.
# Graph document 553 successfully created and saved.
# Graph document 554 successfully created and saved.
# Graph document 555 successfully created and saved.
# Graph document 556 successfully created and saved.
# Graph document 557 successfully created and saved.
# Graph document 558 successfully created and saved.
# Graph document 559 successfully created and saved.
# Graph document 560 successfully created and saved.
# Graph document 561 successfully created and saved.
# Graph document 562 successfully created and saved.
# Error processing document: nd Drona
# do not respect you now as they did befor... - Skipping. Error: Connection error.
# Error processing document: ing the Sindhu king, will
# surely lose heart. They... - Skipping. Error: Connection error.
# Error processing document: it, go and stop Arjuna. I cannot do so for my pres... - Skipping. Error: Connection error.
# Error processing document:  to attack
# Arjuna.
# Arjuna had crossed the Kaura... - Skipping. Error: Connection error.
# Error processing document:
# the Kaurava.
# Duryod hana approached without fe... - Skipping. Error: Connection error.
# Error processing document: na proceeded to shoot
# his arrows, first depriving... - Skipping. Error: Connection error.
# Error processing document: l this, the Kaurava army had to fight on
# three fr... - Skipping. Error: Connection error.
# Error processing document: s red
# with anger, advanced on Satyaki who was
# am... - Skipping. Error: Connection error.
# Error processing document: ofusely.
# The warriors on either side stood still ... - Skipping. Error: Connection error.
# Error processing document: in archery then resolved on killing Satyaki
# and s... - Skipping. Error: Connection error.
# Error processing document: a's
# bow does not accompany it. I fear Arjuna
# has... - Skipping. Error: Connection error.
# Error processing document: Satyaki, who was weary after his battle
# with Dron... - Skipping. Error: Connection error.
# Error processing document: ntrust your safety if I must go? I see no
# one her... - Skipping. Error: Connection error.
# Error processing document:   was slow.
# When Drona saw Satyaki part from
# Yu... - Skipping. Error: Connection error.
# Error processing document: ed hero, in whom
# were centerd all our hopes, has ... - Skipping. Error: Connection error.
# Error processing document: The Kauravas surrounded Bhima in full
# force and v... - Skipping. Error: Connection error.
# Error processing document: ave
# yourself said you are our enemy. May it
# be s... - Skipping. Error: Connection error.
# Error processing document: ing so
# many of his brothers slain, it is possible... - Skipping. Error: Connection error.
# Error processing document: ectively prevented t he relief of
# Abhimanyu by th... - Skipping. Error: Connection error.
# Error processing document:  each side was exposed to
# danger in its rear.
# D... - Skipping. Error: Connection error.
# Error processing document: ly." Puzzled and perplexed, thus did
# Duryodhana p... - Skipping. Error: Connection error.
# Graph document 584 successfully created and saved.
# Graph document 585 successfully created and saved.
# Graph document 586 successfully created and saved.
# Graph document 587 successfully created and saved.
# Graph document 588 successfully created and saved.
# Graph document 589 successfully created and saved.
# Graph document 590 successfully created and saved.
# Graph document 591 successfully created and saved.
# Graph document 592 successfully created and saved.
# Graph document 593 successfully created and saved.
# Graph document 594 successfully created and saved.
# Graph document 595 successfully created and saved.
# Graph document 596 successfully created and saved.
# Graph document 597 successfully created and saved.
# Graph document 598 successfully created and saved.
# Error processing document:  lion drags its elephant prey.
# Arjuna was in a g... - Skipping. Error: Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "DynamicGraph"\n\t\t},\n\t\t"parameters": {\n\t\t\t"nodes": [\n\t\t\t\t{\n\t\t\t\t\t"id": "Arjuna",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Bhurisravas",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Satyaki",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Jayadratha",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Krishna",\n\t\t\t\t\t"type": "person"\n\t\t\t\t}\n\t\t\t],\n\t\t\t"relationships": [\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Arjuna",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": "Krishna",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\t\t"type": "talks_to"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Jayadratha",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "shoots_arrow"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Arjuna",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": "Jayadratha",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\t\t"type": "responds_to"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Arjuna",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": "Satyaki",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\t\t"type": "protects"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Bhurisravas",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": "Satyaki",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\t\t"type": "attacks"\n\t\t\t\t}\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Graph document 600 successfully created and saved.
# Graph document 601 successfully created and saved.
# Graph document 602 successfully created and saved.
# Graph document 603 successfully created and saved.
# Graph document 604 successfully created and saved.
# Graph document 605 successfully created and saved.
# Graph document 606 successfully created and saved.
# Graph document 607 successfully created and saved.
# Graph document 608 successfully created and saved.
# Graph document 609 successfully created and saved.
# Graph document 610 successfully created and saved.
# Graph document 611 successfully created and saved.
# Graph document 612 successfully created and saved.
# Graph document 613 successfully created and saved.
# Graph document 614 successfully created and saved.
# Graph document 615 successfully created and saved.
# Graph document 616 successfully created and saved.
# Graph document 617 successfully created and saved.
# Graph document 618 successfully created and saved.
# Graph document 619 successfully created and saved.
# Graph document 620 successfully created and saved.
# Graph document 621 successfully created and saved.
# Graph document 622 successfully created and saved.
# Graph document 623 successfully created and saved.
# Graph document 624 successfully created and saved.
# Graph document 625 successfully created and saved.
# Graph document 626 successfully created and saved.
# Graph document 627 successfully created and saved.
# Graph document 628 successfully created and saved.
# Graph document 629 successfully created and saved.
# Graph document 630 successfully created and saved.
# Graph document 631 successfully created and saved.
# Graph document 632 successfully created and saved.
# Graph document 633 successfully created and saved.
# Graph document 634 successfully created and saved.
# Graph document 635 successfully created and saved.
# Graph document 636 successfully created and saved.
# Graph document 637 successfully created and saved.
# Graph document 638 successfully created and saved.
# Graph document 639 successfully created and saved.
# Graph document 640 successfully created and saved.
# Graph document 641 successfully created and saved.
# Graph document 642 successfully created and saved.
# Graph document 643 successfully created and saved.
# Graph document 644 successfully created and saved.
# Graph document 645 successfully created and saved.
# Graph document 646 successfully created and saved.
# Graph document 647 successfully created and saved.
# Graph document 648 successfully created and saved.
# Graph document 649 successfully created and saved.
# Graph document 650 successfully created and saved.
# Graph document 651 successfully created and saved.
# Graph document 652 successfully created and saved.
# Error processing document:  spotless purity, this is for you.
# The man, who k... - Skipping. Error: Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "DynamicGraph"\n\t\t},\n\t\t"parameters": {\n\t\t\t"nodes": [\n\t\t\t\t{\n\t\t\t\t\t"id": "Duryodhana",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Duhsasana",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Draupadi",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Yudhishthira",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Dhritarashtra",\n\t\t\t\t\t"type": "person"\n\t\t\t\t}\n\t\t\t],\n\t\t\t"relationships": [\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Duryodhana",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "killed"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Duhsasana",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "killed"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Draupadi",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": "Yudhishthira",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\t\t"type": "bowed"\n\t\t\t\t}\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Graph document 654 successfully created and saved.
# Graph document 655 successfully created and saved.
# Graph document 656 successfully created and saved.
# Graph document 657 successfully created and saved.
# Graph document 658 successfully created and saved.
# Graph document 659 successfully created and saved.
# Graph document 660 successfully created and saved.
# Graph document 661 successfully created and saved.
# Graph document 662 successfully created and saved.
# Graph document 663 successfully created and saved.
# Graph document 664 successfully created and saved.
# Graph document 665 successfully created and saved.
# Graph document 666 successfully created and saved.
# Graph document 667 successfully created and saved.
# Graph document 668 successfully created and saved.
# Graph document 669 successfully created and saved.
# Graph document 670 successfully created and saved.
# Graph document 671 successfully created and saved.
# Graph document 672 successfully created and saved.
# Graph document 673 successfully created and saved.
# Graph document 674 successfully created and saved.
# Graph document 675 successfully created and saved.
# Graph document 676 successfully created and saved.
# Graph document 677 successfully created and saved.
# Graph document 678 successfully created and saved.
# Graph document 679 successfully created and saved.
# Graph document 680 successfully created and saved.
# Graph document 681 successfully created and saved.
# Graph document 682 successfully created and saved.
# Graph document 683 successfully created and saved.
# Graph document 684 successfully created and saved.
# Graph document 685 successfully created and saved.
# Graph document 686 successfully created and saved.
# Graph document 687 successfully created and saved.
# Graph document 688 successfully created and saved.
# Graph document 689 successfully created and saved.
# Graph document 690 successfully created and saved.
# ...
# Error processing document: the names of Vishnu and
# means the Supreme Being. ... - Skipping. Error: Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "DynamicGraph"\n\t\t},\n\t\t"parameters": {\n\t\t\t"nodes": [\n\t\t\t\t{\n\t\t\t\t\t"id": "Vishnu",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Raibhya",\n\t\t\t\t\t"type": "sage"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Bharata",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Dasaratha",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Indra",\n\t\t\t\t\t"type": "god"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Vritra",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Sanatkumar",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Aditi",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Radheya",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Radha",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Karna",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Adhiratha",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Rajasuya",\n\t\t\t\t\t"type": "event"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Ravana",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Sita",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Ramachandra",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Rishabha",\n\t\t\t\t\t"type": "concept"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Rishyasringa",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Vibhandaka",\n\t\t\t\t\t"type": "person"\n\t\t\t\t}\n\t\t\t],\n\t\t\t"relationships": [\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Vishnu",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "is_the_supreme_being"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Raibhya",\n\t\t\t\t\t"source_node_type": "sage",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "had_a_hermitage"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Raibhya",\n\t\t\t\t\t"source_node_type": "sage",\n\t\t\t\t\t"target_node_id": "Pandavas",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\t\t"type": "was_visited_by"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Bharata",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": "Dasaratha",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\t\t"type": "is_son_of"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Indra",\n\t\t\t\t\t"source_node_type": "god",\n\t\t\t\t\t"target_node_id": "Vritra",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\t\t"type": "killed"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Sanatkumar",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "became_one_with_god"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Aditi",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "prayed_to_be_blessed_with_a_son"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Radheya",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": "Radha",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\t\t"type": "was_brought_up_by"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Radheya",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": "Karna",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\t\t"type": "is_a_name_of"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Radheya",\n\t\t\t\ ...
# Graph document 741 successfully created and saved.
# Graph document 742 successfully created and saved.
# Graph document 743 successfully created and saved.
# Graph document 744 successfully created and saved.
# Graph document 745 successfully created and saved.
# Graph document 746 successfully created and saved.
# Error processing document: ults of
# their good deeds on earth.
# Sveta :  A s... - Skipping. Error: Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "DynamicGraph"\n\t\t},\n\t\t"parameters": {\n\t\t\t"nodes": [\n\t\t\t\t{\n\t\t\t\t\t"id": "Sveta",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Tantripala",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Sahadeva",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Uddalaka",\n\t\t\t\t\t"type": "sage"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Umadevi",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Unchhavritti",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Upachitr a",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Upaplavya",\n\t\t\t\t\t"type": "location"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Urvasi",\n\t\t\t\t\t"type": "apsara"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Arjuna",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Vaisampayana",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Vyasa",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Duryodhana",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Vishnu",\n\t\t\t\t\t"type": "deity"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Indra",\n\t\t\t\t\t"type": "deity"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Visvarupa",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "King Virata",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Bhishma",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "King Dhritarashtra",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Siva",\n\t\t\t\t\t"type": "deity"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Yayati",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Mandhata",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Bharata",\n\t\t\t\t\t"type": "person"\n\t\t\t\t}\n\t\t\t],\n\t\t\t"relationships": [\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Sveta",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": "King Virata",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\t\t"type": "son"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Tantripala",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": "Sahadeva",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\t\t"type": "assumed_name"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Uddalaka",\n\t\t\t\t\t"source_node_type": "sage",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "teacher"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Umadevi",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": "Siva",\n\t\t\t\t\t"target_node_type": "deity",\n\t\t\t\t\t"type": "wife"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Unchhavritti",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "mendicant"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Upachitr a",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": "King Dhritarashtra",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\t\t"type": "son"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Upaplavya",\n\t\t\t\t\t"source_node_type": "location",\n\t\t\t\t\t"target_node_id": "Pandavas",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\t\t"type": "settled_after_exile"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Urvasi",\n\t\t\t\t\t"source_node_type": "apsara",\n\t\t\t\t\t"target_node_id": "Arjuna",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\ ...
# Graph document 748 successfully created and saved.
# Graph document 749 successfully created and saved.
# Error processing document: ption in the Bhagavad
# Gita chapter eleven.
# Vrid... - Skipping. Error: Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "DynamicGraph"\n\t\t},\n\t\t"parameters": {\n\t\t\t"nodes": [\n\t\t\t\t{\n\t\t\t\t\t"id": "Vriddhakshatra",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Jayadratha",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Arjuna",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Vrika",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Achala",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Sakuni",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Vrishnis",\n\t\t\t\t\t"type": "tribal"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Kekayas",\n\t\t\t\t\t"type": "tribal"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Sri Krishna",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Pandavas",\n\t\t\t\t\t"type": "group"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Vrishasena",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Twashta",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Indra",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Vritra",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Vajrayudha",\n\t\t\t\t\t"type": "weapon"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Bhima",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Vyasa",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Parasara",\n\t\t\t\t\t"type": "person"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Vyuha",\n\t\t\t\t\t"type": "battle_array"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Yama",\n\t\t\t\t\t"type": "god"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"id": "Yudhishthira",\n\t\t\t\t\t"type": "person"\n\t\t\t\t}\n\t\t\t],\n\t\t\t"relationships": [\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Vriddhakshatra",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": "Jayadratha",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\t\t"type": "father"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Arjuna",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": "Jayadratha",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\t\t"type": "killed"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Vrika",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "died_in_battle"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Achala",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_node_type": null,\n\t\t\t\t\t"type": "brother_of"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Sakuni",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": "Achala",\n\t\t\t\t\t"target_node_type": "person",\n\t\t\t\t\t"type": "brother"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Vrishnis",\n\t\t\t\t\t"source_node_type": "tribal",\n\t\t\t\t\t"target_node_id": "Pandavas",\n\t\t\t\t\t"target_node_type": "group",\n\t\t\t\t\t"type": "allied_to"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Kekayas",\n\t\t\t\t\t"source_node_type": "tribal",\n\t\t\t\t\t"target_node_id": "Pandavas",\n\t\t\t\t\t"target_node_type": "group",\n\t\t\t\t\t"type": "allied_to"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Sri Krishna",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": "Pandavas",\n\t\t\t\t\t"target_node_type": "group",\n\t\t\t\t\t"type": "visited"\n\t\t\t\t},\n\t\t\t\t{\n\t\t\t\t\t"source_node_id": "Vrishasena",\n\t\t\t\t\t"source_node_type": "person",\n\t\t\t\t\t"target_node_id": null,\n\t\t\t\t\t"target_nod ...
# Graph document 751 successfully created and saved.

# %%
for graph_document in graph_documents:
    if hasattr(graph_document, 'relationships'):
        print(graph_document.relationships)
    else:
        print("This document has no relationships attribute.")
# Out:
# [Relationship(source=Node(id='Mahabharata', type='Book'), target=Node(id='C. Rajagopalachari', type='Person'), type='_RETOLD_BY_'), Relationship(source=Node(id='Mahabharata', type='Book'), target=Node(id='Jay Mazo', type='Person'), type='EDITED_BY'), Relationship(source=Node(id='Mahabharata', type='Book'), target=Node(id='International Gita Society', type='Organization'), type='PUBLISHED_BY')]
# []
# [Relationship(source=Node(id='Yudhishthira', type='Person'), target=Node(id='Karna', type='Person'), type='RELATIONSHIP')]
# [Relationship(source=Node(id='Ramayana', type='Person'), target=Node(id='Sita', type='Person'), type='RELATED_TO'), Relationship(source=Node(id='Ramayana', type='Person'), target=Node(id='Rama', type='Person'), type='RELATED_TO'), Relationship(source=Node(id='Mahabharata', type='Person'), target=Node(id='Draupadi', type='Person'), type='RELATED_TO'), Relationship(source=Node(id='Mahabharata', type='Person'), target=Node(id='Arjuna', type='Person'), type='RELATED_TO'), Relationship(source=Node(id='Mahabharata', type='Person'), target=Node(id='Lakshmana', type='Person'), type='RELATED_TO'), Relationship(source=Node(id='Mahabharata', type='Person'), target=Node(id='Hanuman', type='Person'), type='RELATED_TO'), Relationship(source=Node(id='Mahabharata', type='Person'), target=Node(id='Vyasa', type='Person'), type='AUTHOR'), Relationship(source=Node(id='Ramayana', type='Person'), target=Node(id='Valmiki', type='Person'), type='AUTHOR')]
# [Relationship(source=Node(id='The Mahabharata', type='Epic'), target=Node(id='India', type='Country'), type='ORIGINATES_FROM'), Relationship(source=Node(id='The Mahabharata', type='Epic'), target=Node(id='Human Family', type='Group'), type='RELATES_TO')]
# [Relationship(source=Node(id='Mahabharata', type='Book'), target=Node(id='Vyasa', type='Person'), type='AUTHORED')]
# [Relationship(source=Node(id='Pandavas', type='Person'), target=Node(id='Kunti', type='Person'), type='PARENT'), Relationship(source=Node(id='Draupadi', type='Person'), target=Node(id='Kunti', type='Person'), type='CHILD'), Relationship(source=Node(id='Gandhari', type='Person'), target=Node(id='Dhritarashtra', type='Person'), type='SPOUSE')]
# [Relationship(source=Node(id='Emperor', type='Person'), target=Node(id='Royalties', type='Person'), type='ACQUIESCENCE'), Relationship(source=Node(id='Emperor', type='Person'), target=Node(id='Kshatriyas', type='Person'), type='OVERLORDSHIP')]
# [Relationship(source=Node(id='Ashramas', type='Person'), target=Node(id='Young Men', type='Person'), type='EDUCATION'), Relationship(source=Node(id='Ashramas', type='Person'), target=Node(id='Aged', type='Person'), type='PEACE'), Relationship(source=Node(id='Rulers', type='Person'), target=Node(id='Hermitages', type='Person'), type='RESPECT'), Relationship(source=Node(id='Women', type='Person'), target=Node(id='Husbands', type='Person'), type='LIFE'), Relationship(source=Node(id='Women', type='Person'), target=Node(id='Sons', type='Person'), type='LIFE'), Relationship(source=Node(id='Brahmanas', type='Person'), target=Node(id='Mahabharata', type='Person'), type='CHARACTER')]
# [Relationship(source=Node(id='Bhagavan Vyasa', type='Person'), target=Node(id='Parasara', type='Person'), type='SON'), Relationship(source=Node(id='Bhagavan Vyasa', type='Person'), target=Node(id='Mahabharata', type='Epic'), type='COMPILER'), Relationship(source=Node(id='Bhagavan Vyasa', type='Person'), target=Node(id='Brahma', type='Person'), type='PRAYER'), Relationship(source=Node(id='Brahma', type='Person'), target=Node(id='Bhagavan Vyasa', type='Person'), type='EXTOL'), Relationship(source=Node(id='Bhagavan Vyasa', type='Person'), target=Node(id='Ganapati', type='Person'), type='REQUEST')]
# [Relationship(source=Node(id='Vyasa', type='Person'), target=Node(id='Ganapati', type='Person'), type='REQUESTED_AID')]
# [Relationship(source=Node(id='Mahabharata', type='Book'), target=Node(id='Ganapati', type='Person'), type='WROTE'), Relationship(source=Node(id='Mahabharata', type='Book'), target=Node(id='Vyasa', type='Person'), type='AUTHORED'), Relationship(source=Node(id='Vyasa', type='Person'), target=Node(id='Suka', type='Person'), type='TAUGHT'), Relationship(source=Node(id='Vyasa', type='Person'), target=Node(id='Vaisampayana', type='Person'), type='TAUGHT'), Relationship(source=Node(id='Suka', type='Person'), target=Node(id='Gandharvas', type='Group'), type='TAUGHT'), Relationship(source=Node(id='Suka', type='Person'), target=Node(id='Rakshasas', type='Group'), type='TAUGHT'), Relationship(source=Node(id='Suka', type='Person'), target=Node(id='Yakshas', type='Group'), type='TAUGHT'), Relationship(source=Node(id='Vaisampayana', type='Person'), target=Node(id='Janamejaya', type='Person'), type='TOLD_TO'), Relationship(source=Node(id='Vaisampayana', type='Person'), target=Node(id='Mahabharata', type='Book'), type='NARRATED'), Relationship(source=Node(id='Suta', type='Person'), target=Node(id='Mahabharata', type='Book'), type='RECITED'), Relationship(source=Node(id='Suta', type='Person'), target=Node(id='Saunaka', type='Person'), type='TOLD_TO')]
# [Relationship(source=Node(id='Vyasa', type='Person'), target=Node(id='Mahabharata', type='Book'), type='COMPOSED'), Relationship(source=Node(id='Suta', type='Person'), target=Node(id='Mahabharata', type='Book'), type='HEARD'), Relationship(source=Node(id='Vaisampayana', type='Person'), target=Node(id='Mahabharata', type='Book'), type='TOLD'), Relationship(source=Node(id='Vaisampayana', type='Person'), target=Node(id='King Janamejaya', type='Person'), type='TOLD_TO'), Relationship(source=Node(id='Santanu', type='Person'), target=Node(id='Chitrangada', type='Person'), type='SUCCEEDED'), Relationship(source=Node(id='Chitrangada', type='Person'), target=Node(id='Vichitravirya', type='Person'), type='SUCCEEDED'), Relationship(source=Node(id='Vichitravirya', type='Person'), target=Node(id='Dhritarashtra', type='Person'), type='SON'), Relationship(source=Node(id='Vichitravirya', type='Person'), target=Node(id='Pandu', type='Person'), type='SON')]
# [Relationship(source=Node(id='Ndu', type='Person'), target=Node(id='Kunti', type='Person'), type='SPOUSE'), Relationship(source=Node(id='Ndu', type='Person'), target=Node(id='Madri', type='Person'), type='SPOUSE'), Relationship(source=Node(id='Kunti', type='Person'), target=Node(id='Pandavas', type='Group'), type='PARENT'), Relationship(source=Node(id='Madri', type='Person'), target=Node(id='Pandavas', type='Group'), type='PARENT'), Relationship(source=Node(id='Pandu', type='Person'), target=Node(id='Pandavas', type='Group'), type='PARENT'), Relationship(source=Node(id='Yudhishthira', type='Person'), target=Node(id='Pandavas', type='Group'), type='MEMBER'), Relationship(source=Node(id='Pandavas', type='Group'), target=Node(id='Bhishma', type='Person'), type='GUARDIAN'), Relationship(source=Node(id='Pandavas', type='Group'), target=Node(id='Kauravas', type='Group'), type='RIVAL')]
# [Relationship(source=Node(id='Kauravas', type='Group'), target=Node(id='Sakuni', type='Person'), type='MEMBER'), Relationship(source=Node(id='Pandavas', type='Group'), target=Node(id='Yudhishthira', type='Person'), type='MEMBER'), Relationship(source=Node(id='Pandavas', type='Group'), target=Node(id='Draupadi', type='Person'), type='SPOUSE'), Relationship(source=Node(id='Kauravas', type='Group'), target=Node(id='Duryodhana', type='Person'), type='MEMBER'), Relationship(source=Node(id='Pandavas', type='Group'), target=Node(id='Parikshit', type='Person'), type='DESCENDANT'), Relationship(source=Node(id='Pandavas', type='Group'), target=Node(id='Indraprastha', type='City'), type='RULE'), Relationship(source=Node(id='Pandavas', type='Group'), target=Node(id='Hastinapura', type='City'), type='RULE'), Relationship(source=Node(id='Kauravas', type='Group'), target=Node(id='Hastinapura', type='City'), type='RULE')]
# [Relationship(source=Node(id='Santanu', type='Person'), target=Node(id='Ganga', type='Person'), type='MARRIAGEPROPOSAL')]
# [Relationship(source=Node(id='Santanu', type='Person'), target=Node(id='Ganga', type='Person'), type='MARRIED_TO')]
# [Relationship(source=Node(id='Ganga', type='Person'), target=Node(id='Eight Vasus', type='Person'), type='MOTHER'), Relationship(source=Node(id='Vasishtha', type='Person'), target=Node(id='Eight Vasus', type='Person'), type='CURSED'), Relationship(source=Node(id='Santanu', type='Person'), target=Node(id='Ganga', type='Person'), type='KING')]
# [Relationship(source=Node(id='Vasishtha', type='Person'), target=Node(id='Nandini', type='Cow'), type='OWNS'), Relationship(source=Node(id='Vasus', type='Group'), target=Node(id='Nandini', type='Cow'), type='ATTEMPTED_THEFT'), Relationship(source=Node(id='Vasishtha', type='Person'), target=Node(id='Vasus', type='Group'), type='CURSED'), Relationship(source=Node(id='Vasus', type='Group'), target=Node(id='Bhishma', type='Person'), type='PARENT')]
# [Relationship(source=Node(id='Vasishtha', type='Sage'), target=Node(id='Cow', type='Animal'), type='OWNS'), Relationship(source=Node(id='Vasishtha', type='Sage'), target=Node(id='Calf', type='Animal'), type='OWNS'), Relationship(source=Node(id='Vasus', type='Group'), target=Node(id='Cow', type='Animal'), type='TAKES'), Relationship(source=Node(id='Vasus', type='Group'), target=Node(id='Calf', type='Animal'), type='TAKES'), Relationship(source=Node(id='Vasishtha', type='Sage'), target=Node(id='Vasus', type='Group'), type='CURSES'), Relationship(source=Node(id='Vasus', type='Group'), target=Node(id='Vasishtha', type='Sage'), type='APOLOGIZES')]
# [Relationship(source=Node(id='Vasishtha', type='Person'), target=Node(id='Vasus', type='Group'), type='CURSED'), Relationship(source=Node(id='Vasus', type='Group'), target=Node(id='Ganga', type='Goddess'), type='REQUESTED_MOTHER'), Relationship(source=Node(id='Ganga', type='Goddess'), target=Node(id='Santanu', type='Person'), type='MARRIED'), Relationship(source=Node(id='Santanu', type='Person'), target=Node(id='Devendra', type='Person'), type='PARENT')]
# [Relationship(source=Node(id='Ganga', type='Person'), target=Node(id='Devavrata', type='Person'), type='MOTHER'), Relationship(source=Node(id='Ganga', type='Person'), target=Node(id='King', type='Person'), type='REVEALED_CHILD'), Relationship(source=Node(id='King', type='Person'), target=Node(id='Devavrata', type='Person'), type='FATHER'), Relationship(source=Node(id='Devavrata', type='Person'), target=Node(id='Vasishtha', type='Person'), type='LEARNED_FROM'), Relationship(source=Node(id='Devavrata', type='Person'), target=Node(id='Sukra', type='Person'), type='LEARNED_FROM'), Relationship(source=Node(id='Devavrata', type='Person'), target=Node(id='Parasurama', type='Person'), type='EQUALS_IN_PROWESS')]
# [Relationship(source=Node(id='Santsantanu', type='Person'), target=Node(id='Maiden', type='Person'), type='DESIRED_SPOUSE'), Relationship(source=Node(id='Maiden', type='Person'), target=Node(id='Fisherman_Chief', type='Person'), type='DAUGHTER'), Relationship(source=Node(id='Santsantanu', type='Person'), target=Node(id='Ganga', type='Person'), type='FORMER_SPOUSE')]
# [Relationship(source=Node(id='The King', type='Person'), target=Node(id='Devavrata', type='Person'), type='SON'), Relationship(source=Node(id='The Chief Of The Fisherfolk', type='Person'), target=Node(id='The Child Born Of The Maiden', type='Person'), type='PARENT'), Relationship(source=Node(id='The King', type='Person'), target=Node(id='Hastinapura', type='Location'), type='RULER')]
# [Relationship(source=Node(id='The Father', type='Person'), target=Node(id='The Son', type='Person'), type='PARENT'), Relationship(source=Node(id='The Wise Devavrata', type='Person'), target=Node(id='The Father', type='Person'), type='REALIZED'), Relationship(source=Node(id='The Wise Devavrata', type='Person'), target=Node(id="The King'S Charioteer", type='Person'), type='QUESTIONED'), Relationship(source=Node(id='The Wise Devavrata', type='Person'), target=Node(id='The Chief Of The Fishermen', type='Person'), type='BESOUGHT'), Relationship(source=Node(id='The Chief Of The Fishermen', type='Person'), target=Node(id='The Fishermaiden', type='Person'), type='DAUGHTER')]
# [Relationship(source=Node(id='Devavrata', type='Person'), target=Node(id='King', type='Person'), type='HEIR_APPARENT'), Relationship(source=Node(id='Devavrata', type='Person'), target=Node(id='Maiden', type='Person'), type='RELATIONSHIP'), Relationship(source=Node(id='Chief_Of_The_Fishermen', type='Person'), target=Node(id='King', type='Person'), type='FATHER')]
# [Relationship(source=Node(id='Bhishma', type='Person'), target=Node(id='Devavrata', type='Person'), type='EPITHET'), Relationship(source=Node(id='Devavrata', type='Person'), target=Node(id='Satyavati', type='Person'), type='SPOUSE'), Relationship(source=Node(id='Satyavati', type='Person'), target=Node(id='Santanu', type='Person'), type='SPOUSE'), Relationship(source=Node(id='Santanu', type='Person'), target=Node(id='Chitrangada', type='Person'), type='PARENT'), Relationship(source=Node(id='Santanu', type='Person'), target=Node(id='Vichitravirya', type='Person'), type='PARENT'), Relationship(source=Node(id='Vichitravirya', type='Person'), target=Node(id='Dhritarashtra', type='Person'), type='PARENT'), Relationship(source=Node(id='Vichitravirya', type='Person'), target=Node(id='Pandu', type='Person'), type='PARENT'), Relationship(source=Node(id='Dhritarashtra', type='Person'), target=Node(id='Kauravas', type='Person'), type='PARENT'), Relationship(source=Node(id='Pandu', type='Person'), target=Node(id='Pandavas', type='Person'), type='PARENT')]
# [Relationship(source=Node(id='Santanu', type='Person'), target=Node(id='Chitrangada', type='Person'), type='PARENT'), Relationship(source=Node(id='Santanu', type='Person'), target=Node(id='Vichitravirya', type='Person'), type='PARENT'), Relationship(source=Node(id='Chitrangada', type='Person'), target=Node(id='Vichitravirya', type='Person'), type='BROTHER'), Relationship(source=Node(id='Santanu', type='Person'), target=Node(id='Dhritarashtra', type='Person'), type='PARENT'), Relationship(source=Node(id='Santanu', type='Person'), target=Node(id='Pandu', type='Person'), type='PARENT'), Relationship(source=Node(id='Satyavati', type='Person'), target=Node(id='Bhishma', type='Person'), type='PARENT'), Relationship(source=Node(id='Ambika', type='Person'), target=Node(id='Dhritarashtra', type='Person'), type='PARENT'), Relationship(source=Node(id='Ambalika', type='Person'), target=Node(id='Pandu', type='Person'), type='PARENT'), Relationship(source=Node(id='Bhishma', type='Person'), target=Node(id='Vichitravirya', type='Person'), type='GUARDIAN')]
# [Relationship(source=Node(id='Bhishma', type='Person'), target=Node(id='Vichitravirya', type='Person'), type='BROTHER')]
# [Relationship(source=Node(id='Bhishma', type='Person'), target=Node(id='Amba', type='Person'), type='KIDNAPPED'), Relationship(source=Node(id='Amba', type='Person'), target=Node(id='Salva', type='Person'), type='CHOSEN_HUSBAND'), Relationship(source=Node(id='Bhishma', type='Person'), target=Node(id='Vichitravirya', type='Person'), type='ARRANGED_MARRIAGE')]
# [Relationship(source=Node(id='Amba', type='Person'), target=Node(id='Salva', type='Person'), type='ENGAGED_TO'), Relationship(source=Node(id='Ambika', type='Person'), target=Node(id='Vichitravirya', type='Person'), type='MARRIED'), Relationship(source=Node(id='Ambalika', type='Person'), target=Node(id='Vichitravirya', type='Person'), type='MARRIED'), Relationship(source=Node(id='Amba', type='Person'), target=Node(id='Bhishma', type='Person'), type='SENT_BY'), Relationship(source=Node(id='Bhishma', type='Person'), target=Node(id='Amba', type='Person'), type='CARRIED_AWAY')]
# [Relationship(source=Node(id='Amba', type='Person'), target=Node(id='Vichitravirya', type='Person'), type='LOVES'), Relationship(source=Node(id='Amba', type='Person'), target=Node(id='Salva', type='Person'), type='SEEKS'), Relationship(source=Node(id='Amba', type='Person'), target=Node(id='Bhishma', type='Person'), type='HATES'), Relationship(source=Node(id='Amba', type='Person'), target=Node(id='Lord Subrahmanya', type='Person'), type='WORSHIPS')]
# [Relationship(source=Node(id='Amba', type='Person'), target=Node(id='Bhishma', type='Person'), type='REVENGE'), Relationship(source=Node(id='Amba', type='Person'), target=Node(id='King Drupada', type='Person'), type='REQUEST'), Relationship(source=Node(id='Amba', type='Person'), target=Node(id='Parasurama', type='Person'), type='SUPPLICATION'), Relationship(source=Node(id='Parasurama', type='Person'), target=Node(id='Bhishma', type='Person'), type='FIGHT')]
# [Relationship(source=Node(id='Parasurama', type='Person'), target=Node(id='Amba', type='Person'), type='DEFEATED'), Relationship(source=Node(id='Amba', type='Person'), target=Node(id='Siva', type='Person'), type='WORSHIPPED'), Relationship(source=Node(id='Siva', type='Person'), target=Node(id='Amba', type='Person'), type='GRANTED_BOON'), Relationship(source=Node(id='Amba', type='Person'), target=Node(id='Bhishma', type='Person'), type='SLAY_IN_NEXT_LIFE'), Relationship(source=Node(id='Amba', type='Person'), target=Node(id='King Drupada', type='Person'), type='BORN_AS_DAUGHTER')]
# [Relationship(source=Node(id='Drupada', type='Person'), target=Node(id='Devayani', type='Person'), type='FATHER'), Relationship(source=Node(id='Devayani', type='Person'), target=Node(id='Sikhandin', type='Person'), type='TRANSFORMED_FROM'), Relationship(source=Node(id='Sikhandin', type='Person'), target=Node(id='Arjuna', type='Person'), type='CHARIOTEER'), Relationship(source=Node(id='Arjuna', type='Person'), target=Node(id='Bhishma', type='Person'), type='FOUGHT')]
# [Relationship(source=Node(id='Kacha', type='Person'), target=Node(id='Brihaspati', type='Person'), type='SON'), Relationship(source=Node(id='Brihaspati', type='Person'), target=Node(id='Devas', type='Group'), type='PRECEPTOR'), Relationship(source=Node(id='Sukracharya', type='Person'), target=Node(id='Asuras', type='Group'), type='PRECEPTOR')]
# [Relationship(source=Node(id='Kacha', type='Person'), target=Node(id='Sukracharya', type='Person'), type='PUPIL_TEACHER'), Relationship(source=Node(id='Kacha', type='Person'), target=Node(id='Devayani', type='Person'), type='SERVES'), Relationship(source=Node(id='Kacha', type='Person'), target=Node(id='Brihaspati', type='Person'), type='SON'), Relationship(source=Node(id='Kacha', type='Person'), target=Node(id='Angiras', type='Person'), type='GRANDSON'), Relationship(source=Node(id='Sukracharya', type='Person'), target=Node(id='Vrishaparva', type='Person'), type='RESIDES_IN')]
# [Relationship(source=Node(id='Kacha', type='Person'), target=Node(id='Devayani', type='Person'), type='LOVED'), Relationship(source=Node(id='Kacha', type='Person'), target=Node(id='Sukracharya', type='Person'), type='STUDENT'), Relationship(source=Node(id='Asuras', type='Group'), target=Node(id='Kacha', type='Person'), type='ATTACKED')]
# [Relationship(source=Node(id='Devayani', type='Person'), target=Node(id='Kacha', type='Person'), type='LOVES'), Relationship(source=Node(id='Kacha', type='Person'), target=Node(id='Asuras', type='Group'), type='KILLED'), Relationship(source=Node(id='Devayani', type='Person'), target=Node(id='Sukracharya', type='Person'), type='DAUGHTER')]
# [Relationship(source=Node(id='Devayani', type='Person'), target=Node(id='Kacha', type='Person'), type='LOVED'), Relationship(source=Node(id='Sukracharya', type='Person'), target=Node(id='Devayani', type='Person'), type='DAUGHTER'), Relationship(source=Node(id='Kacha', type='Person'), target=Node(id='Angiras', type='Person'), type='GRANDSON'), Relationship(source=Node(id='Kacha', type='Person'), target=Node(id='Brihaspati', type='Person'), type='SON')]
# [Relationship(source=Node(id='Sukracharya', type='Person'), target=Node(id='Kacha', type='Person'), type='ANGERED'), Relationship(source=Node(id='Sukracharya', type='Person'), target=Node(id='Asuras', type='Group'), type='BLAME'), Relationship(source=Node(id='Sukracharya', type='Person'), target=Node(id='Devas', type='Group'), type='SUPPORT')]
# [Relationship(source=Node(id='Kacha', type='Person'), target=Node(id='Devayani', type='Person'), type='CHILD'), Relationship(source=Node(id='Sukracharya', type='Person'), target=Node(id='Kacha', type='Person'), type='TEACHER'), Relationship(source=Node(id='Sukracharya', type='Person'), target=Node(id='Devayani', type='Person'), type='TEACHER')]
# [Relationship(source=Node(id='Kacha', type='Person'), target=Node(id='Sukracharya', type='Person'), type='BORN_FROM'), Relationship(source=Node(id='Kacha', type='Person'), target=Node(id='Sukracharya', type='Person'), type='TAUGHT_BY'), Relationship(source=Node(id='Kacha', type='Person'), target=Node(id='Devayani', type='Person'), type='LOVED_BY'), Relationship(source=Node(id='Kacha', type='Person'), target=Node(id='Devayani', type='Person'), type='MARRIAGE_PROPOSAL')]
# [Relationship(source=Node(id='Kacha', type='Person'), target=Node(id='Sukracharya', type='Person'), type='STUDENT'), Relationship(source=Node(id='Devayani', type='Person'), target=Node(id='Sukracharya', type='Person'), type='DAUGHTER'), Relationship(source=Node(id='Kacha', type='Person'), target=Node(id='Devayani', type='Person'), type='BROTHER')]
# [Relationship(source=Node(id='Arya', type='Person'), target=Node(id='Kacha', type='Person'), type='RELATED_TO'), Relationship(source=Node(id='Kacha', type='Person'), target=Node(id='Indra', type='Person'), type='WENT_TO'), Relationship(source=Node(id='Sukracharya', type='Person'), target=Node(id='Devayani', type='Person'), type='CONSOLED')]
# [Relationship(source=Node(id='Sarmishtha', type='Person'), target=Node(id='Devayani', type='Person'), type='ATTACKED'), Relationship(source=Node(id='Devayani', type='Person'), target=Node(id='Emperor Yayati', type='Person'), type='RESCUED')]
# [Relationship(source=Node(id='Sukracharya', type='Person'), target=Node(id='Devayani', type='Person'), type='FATHER'), Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Devayani', type='Person'), type='HELPED'), Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Devayani', type='Person'), type='MARRY')]
# [Relationship(source=Node(id='Sukracharya', type='Person'), target=Node(id='Devayani', type='Person'), type='FATHER'), Relationship(source=Node(id='Devayani', type='Person'), target=Node(id='Vrishaparva', type='Place'), type='RESIDES_IN')]
# [Relationship(source=Node(id='Sukracharya', type='Person'), target=Node(id='Devayani', type='Person'), type='FATHER'), Relationship(source=Node(id='Sarm Ishtha', type='Person'), target=Node(id='Devayani', type='Person'), type='INSULTED'), Relationship(source=Node(id='Sarm Ishtha', type='Person'), target=Node(id='Vrishaparva', type='Person'), type='DAUGHTER')]
# [Relationship(source=Node(id='Bhagavan Vyasa', type='Person'), target=Node(id='Sukracharya', type='Person'), type='ADVISES'), Relationship(source=Node(id='Sukracharya', type='Person'), target=Node(id='Humanity', type='Group'), type='ADVISES')]
# [Relationship(source=Node(id='Sukracharya', type='Person'), target=Node(id='Vrishaparva', type='Person'), type='GOES_TO')]
# [Relationship(source=Node(id='Kacha', type='Person'), target=Node(id='Brihaspati', type='Person'), type='SON'), Relationship(source=Node(id='Sukracharya', type='Person'), target=Node(id="Sukracharya'S Daughter", type='Person'), type='FATHER'), Relationship(source=Node(id='King Of The Asuras', type='Person'), target=Node(id="Sukracharya'S Daughter", type='Person'), type='PUSHED_INTO_A_WELL'), Relationship(source=Node(id="King Of The Asuras' Daughter", type='Person'), target=Node(id="Sukracharya'S Daughter", type='Person'), type='UTTERED_DISHONORING_WORDS'), Relationship(source=Node(id='Sukracharya', type='Person'), target=Node(id='King Of The Asuras', type='Person'), type='SERVED')]
# [Relationship(source=Node(id='Vrishaparva', type='Person'), target=Node(id='Devayani', type='Person'), type='GOES_TO'), Relationship(source=Node(id='Devayani', type='Person'), target=Node(id='Sarmishtha', type='Person'), type='DEMANDS_TO_BE_ATTENDANT'), Relationship(source=Node(id='Sarmishtha', type='Person'), target=Node(id='Devayani', type='Person'), type='AGREES_TO_BE_ATTENDANT'), Relationship(source=Node(id='Devayani', type='Person'), target=Node(id='Yayati', type='Person'), type='REQUESTS_MARRIAGE')]
# [Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Devayani', type='Person'), type='MARRIED'), Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Sarmishtha', type='Person'), type='MARRIED'), Relationship(source=Node(id='Devayani', type='Person'), target=Node(id='Sukracharya', type='Person'), type='COMPLAINED_TO')]
# [Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Sukracharya', type='Person'), type='CURSED'), Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Devayani', type='Person'), type='WRONGED')]
# [Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Sukracharya', type='Person'), type='ANCESTOR'), Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Eldest Son', type='Person'), type='PARENT'), Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Second Son', type='Person'), type='PARENT')]
# [Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Old Age', type='Concept'), type='AFFLICTED_WITH')]
# [Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Sukracharya', type='Person'), type='CURSED'), Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Puru', type='Person'), type='PARENT'), Relationship(source=Node(id='Puru', type='Person'), target=Node(id='Yayati', type='Person'), type='CHILD'), Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Kubera', type='Person'), type='VISITED'), Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Apsara Maiden', type='Person'), type='SPENT_TIME_WITH')]
# [Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Puru', type='Person'), type='FATHER'), Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Puru', type='Person'), type='GAVE_YOUTH'), Relationship(source=Node(id='Puru', type='Person'), target=Node(id='Yayati', type='Person'), type='BECAME_KING'), Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Forest', type='Location'), type='RETIRED_TO'), Relationship(source=Node(id='Mandavya', type='Person'), target=Node(id='Hermitage', type='Location'), type='LIVED_IN')]
# [Relationship(source=Node(id='The Fugitives', type='Person'), target=Node(id='The Ashrama', type='Location'), type='ENTERED'), Relationship(source=Node(id='The Soldiers', type='Group'), target=Node(id='The Ashrama', type='Location'), type='CAME_TO'), Relationship(source=Node(id='The Commander', type='Person'), target=Node(id='Mandavya', type='Person'), type='ASKED'), Relationship(source=Node(id='The Attendants', type='Group'), target=Node(id='The Ashrama', type='Location'), type='ENTERED'), Relationship(source=Node(id='The Attendants', type='Group'), target=Node(id='The Commander', type='Person'), type='REPORTED'), Relationship(source=Node(id='The Commander', type='Person'), target=Node(id='The Fugitives', type='Person'), type='FOUND')]
# [Relationship(source=Node(id='Chief Of The Robbers', type='Person'), target=Node(id='Mandavya', type='Person'), type='ROBBERY'), Relationship(source=Node(id='Chief Of The Robbers', type='Person'), target=Node(id='King', type='Person'), type='REPORT'), Relationship(source=Node(id='King', type='Person'), target=Node(id='Mandavya', type='Person'), type='IMPALE')]
# [Relationship(source=Node(id='King', type='Person'), target=Node(id='Mandavya', type='Person'), type='IMPALED'), Relationship(source=Node(id='King', type='Person'), target=Node(id='Mandavya', type='Person'), type='FORGAVE'), Relationship(source=Node(id='Mandavya', type='Person'), target=Node(id='Dharma', type='Person'), type='ASKED_QUESTION'), Relationship(source=Node(id='Dharma', type='Person'), target=Node(id='Mandavya', type='Person'), type='ANSWERED'), Relationship(source=Node(id='Mandavya', type='Person'), target=Node(id='Birds', type='Animal'), type='TORTURED'), Relationship(source=Node(id='Mandavya', type='Person'), target=Node(id='Bees', type='Animal'), type='TORTURED')]
# [Relationship(source=Node(id='Lord Dharma', type='Person'), target=Node(id='Vidura', type='Person'), type='INCARNATION'), Relationship(source=Node(id='Sage Mandavya', type='Person'), target=Node(id='Lord Dharma', type='Person'), type='CURSED'), Relationship(source=Node(id='Ambalika', type='Person'), target=Node(id='Vidura', type='Person'), type='BORN_TO'), Relationship(source=Node(id='Vichitravirya', type='Person'), target=Node(id='Ambalika', type='Person'), type='SPOUSE'), Relationship(source=Node(id='Bhishma', type='Person'), target=Node(id='Vidura', type='Person'), type='APPOINTED_AS'), Relationship(source=Node(id='Dhritarashtra', type='Person'), target=Node(id='Vidura', type='Person'), type='RULER'), Relationship(source=Node(id='Vyasa', type='Person'), target=Node(id='Vidura', type='Person'), type='CONSIDERED')]
# [Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Vidura', type='Person'), type='DISAPPROVAL'), Relationship(source=Node(id='Dhritarashtra', type='Person'), target=Node(id='Duryodhana', type='Person'), type='FONDNESS'), Relationship(source=Node(id='Dhritarashtra', type='Person'), target=Node(id='Yudhishthira', type='Person'), type='INVITATION'), Relationship(source=Node(id='Sura', type='Person'), target=Node(id='Pritha', type='Person'), type='PARENT'), Relationship(source=Node(id='Sura', type='Person'), target=Node(id='Kuntibhoja', type='Person'), type='COUSIN'), Relationship(source=Node(id='Sura', type='Person'), target=Node(id='Kunti', type='Person'), type='PARENT'), Relationship(source=Node(id='Durvasa', type='Person'), target=Node(id='Kunti', type='Person'), type='GUEST')]
# [Relationship(source=Node(id='Kunti', type='Person'), target=Node(id='Sun', type='Person'), type='GIVEN_SON_MANTRA')]
# [Relationship(source=Node(id='Kunti', type='Person'), target=Node(id='Sun God', type='Person'), type='PARENT'), Relationship(source=Node(id='Durvasa', type='Person'), target=Node(id='Kunti', type='Person'), type='GRANTS_BOON'), Relationship(source=Node(id='Sun God', type='Person'), target=Node(id='Karna', type='Person'), type='PARENT')]
# [Relationship(source=Node(id='Karna', type='Person'), target=Node(id='Sun God', type='Person'), type='SON'), Relationship(source=Node(id='Karna', type='Person'), target=Node(id='Charioteer', type='Person'), type='RAISED_BY'), Relationship(source=Node(id='Kunti', type='Person'), target=Node(id='King Pandu', type='Person'), type='SPOUSE')]
# [Relationship(source=Node(id='Pandu', type='Person'), target=Node(id='Madri', type='Person'), type='SPOUSE'), Relationship(source=Node(id='Pandu', type='Person'), target=Node(id='Bhishma', type='Person'), type='RULER_ENTRUSTED_KINGDOM_TO'), Relationship(source=Node(id='Pandu', type='Person'), target=Node(id='Vidura', type='Person'), type='RULER_ENTRUSTED_KINGDOM_TO'), Relationship(source=Node(id='Kunti', type='Person'), target=Node(id='Pandu', type='Person'), type='CONFIDED_IN'), Relationship(source=Node(id='Durvasa', type='Person'), target=Node(id='Kunti', type='Person'), type='GAVE_MANTRA_TO')]
# [Relationship(source=Node(id='Kunti', type='Person'), target=Node(id='King Pandu', type='Person'), type='WIFE'), Relationship(source=Node(id='Madri', type='Person'), target=Node(id='King Pandu', type='Person'), type='WIFE'), Relationship(source=Node(id='King Pandu', type='Person'), target=Node(id='Yudhishthira', type='Person'), type='FATHER'), Relationship(source=Node(id='Kunti', type='Person'), target=Node(id='Yudhishthira', type='Person'), type='MOTHER'), Relationship(source=Node(id='Bhishma', type='Person'), target=Node(id='Yudhishthira', type='Person'), type='GUARDIAN')]
# [Relationship(source=Node(id='Pandu', type='Person'), target=Node(id='Vidura', type='Person'), type='RELATED_TO'), Relationship(source=Node(id='Pandu', type='Person'), target=Node(id='Bhishma', type='Person'), type='RELATED_TO'), Relationship(source=Node(id='Pandu', type='Person'), target=Node(id='Vyasa', type='Person'), type='RELATED_TO'), Relationship(source=Node(id='Pandu', type='Person'), target=Node(id='Dhritarashtra', type='Person'), type='RELATED_TO'), Relationship(source=Node(id='Satyavati', type='Person'), target=Node(id='Ambika', type='Person'), type='RELATED_TO'), Relationship(source=Node(id='Satyavati', type='Person'), target=Node(id='Ambalika', type='Person'), type='RELATED_TO'), Relationship(source=Node(id='Pandu', type='Person'), target=Node(id='Bhima', type='Person'), type='PARENT_OF')]
# [Relationship(source=Node(id='Arashtra', type='Person'), target=Node(id='Bhima', type='Person'), type='FATHER'), Relationship(source=Node(id='Bhima', type='Person'), target=Node(id='Duryodhana', type='Person'), type='BULLY'), Relationship(source=Node(id='Bhima', type='Person'), target=Node(id='Kauravas', type='Person'), type='BULLY'), Relationship(source=Node(id='Dhritarashtra', type='Person'), target=Node(id='Duryodhana', type='Person'), type='FATHER'), Relationship(source=Node(id='Kripacharya', type='Person'), target=Node(id='Duryodhana', type='Person'), type='TEACHER')]
# [Relationship(source=Node(id='Ngdom', type='Location'), target=Node(id='Pandu', type='Person'), type='RULED_BY'), Relationship(source=Node(id='Pandu', type='Person'), target=Node(id='Yudhishthira', type='Person'), type='HEIR_APPARENT'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Bhima', type='Person'), type='PLANNED_TO_KILL'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Arjuna', type='Person'), type='PLANNED_TO_IMPRISON'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Yudhishthira', type='Person'), type='PLANNED_TO_IMPRISON'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Ngdom', type='Location'), type='PLANNED_TO_RULE'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Bhima', type='Person'), type='THREW_INTO_RIVER'), Relationship(source=Node(id='Bhima', type='Person'), target=Node(id='Ganges', type='Body_of_water'), type='FELL_INTO')]
# [Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Bhima', type='Person'), type='THREW'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Yudhishthira', type='Person'), type='INFORMED'), Relationship(source=Node(id='Yudhishthira', type='Person'), target=Node(id='Bhima', type='Person'), type='INQUIRED')]
# [Relationship(source=Node(id='Bhima', type='Person'), target=Node(id='Kunti', type='Person'), type='PARENT'), Relationship(source=Node(id='Bhima', type='Person'), target=Node(id='Yudhishthira', type='Person'), type='SIBLING'), Relationship(source=Node(id='Kunti', type='Person'), target=Node(id='Vidura', type='Person'), type='ADVISOR'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Bhima', type='Person'), type='ENEMY')]
# [Relationship(source=Node(id='Arjuna', type='Person'), target=Node(id='Drona', type='Person'), type='LEARNT_FROM'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Drona', type='Person'), type='LEARNT_FROM'), Relationship(source=Node(id='Arjuna', type='Person'), target=Node(id='Kripacharya', type='Person'), type='LEARNT_FROM'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Kripacharya', type='Person'), type='LEARNT_FROM')]
# [Relationship(source=Node(id='Karna', type='Person'), target=Node(id='Arjuna', type='Person'), type='ADDRESSED'), Relationship(source=Node(id='Karna', type='Person'), target=Node(id='Duryodhana', type='Person'), type='ACCEPTED_OFFER'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Karna', type='Person'), type='WELCOMED'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Karna', type='Person'), type='OFFERED_PROSPERITY'), Relationship(source=Node(id='Karna', type='Person'), target=Node(id='Duryodhana', type='Person'), type='EXPRESSED_GRATITUDE')]
# [Relationship(source=Node(id='Karna', type='Person'), target=Node(id='Arjuna', type='Person'), type='CHALLENGED'), Relationship(source=Node(id='Arjuna', type='Person'), target=Node(id='Drona', type='Person'), type='RECEIVED_PERMISSION'), Relationship(source=Node(id='Karna', type='Person'), target=Node(id='Kuru Brothers', type='Group'), type='TOOK_LEAVE'), Relationship(source=Node(id='Arjuna', type='Person'), target=Node(id='Kaurava Brothers', type='Group'), type='EMBRACED'), Relationship(source=Node(id='Indra', type='Person'), target=Node(id='Karna', type='Person'), type='ENCOURAGED'), Relationship(source=Node(id='Bhaskara', type='Person'), target=Node(id='Karna', type='Person'), type='ENCOURAGED'), Relationship(source=Node(id='Kunti', type='Person'), target=Node(id='Karna', type='Person'), type='RECOGNIZED'), Relationship(source=Node(id='Vidura', type='Person'), target=Node(id='Kunti', type='Person'), type='INSTRUCTED')]
# [Relationship(source=Node(id='Kripa', type='Person'), target=Node(id='Karna', type='Person'), type='ADDRESSES'), Relationship(source=Node(id='Kripa', type='Person'), target=Node(id='Partha', type='Person'), type='REFERS_TO'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Karna', type='Person'), type='CROWNS'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Bhishma', type='Person'), type='OBTAINS_ASSENT'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Dhritarashtra', type='Person'), type='OBTAINS_ASSENT'), Relationship(source=Node(id='Karna', type='Person'), target=Node(id='Anga', type='Kingdom'), type='BECOMES_KING_OF'), Relationship(source=Node(id='Karna', type='Person'), target=Node(id='Duryodhana', type='Person'), type='FIGHTS_WITH')]
# [Relationship(source=Node(id='Adhiratha', type='Person'), target=Node(id='Karna', type='Person'), type='FOSTER_FATHER'), Relationship(source=Node(id='Karna', type='Person'), target=Node(id='Anga', type='Place'), type='KING'), Relationship(source=Node(id='Bhima', type='Person'), target=Node(id='Karna', type='Person'), type='CRITICIZES'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Karna', type='Person'), type='SUPPORTS')]
# [Relationship(source=Node(id='Vrikodara', type='Person'), target=Node(id='Karna', type='Person'), type='SPEAKS_TO'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Karna', type='Person'), type='TAKES_IN_CHARIOT'), Relationship(source=Node(id='Indra', type='Person'), target=Node(id='Arjuna', type='Person'), type='IS_FATHER_OF'), Relationship(source=Node(id='Indra', type='Person'), target=Node(id='Karna', type='Person'), type='FORESAW_CONTEST_WITH'), Relationship(source=Node(id='Indra', type='Person'), target=Node(id='Arjuna', type='Person'), type='FORESAW_CONTEST_WITH')]
# [Relationship(source=Node(id='Sun God', type='Person'), target=Node(id='Karna', type='Person'), type='WARNED'), Relationship(source=Node(id='Indra', type='Person'), target=Node(id='Karna', type='Person'), type='DECEIVED'), Relationship(source=Node(id='Karna', type='Person'), target=Node(id='Indra', type='Person'), type='GAVE_GIFT'), Relationship(source=Node(id='Indra', type='Person'), target=Node(id='Karna', type='Person'), type='GRANTED_BOON')]
# [Relationship(source=Node(id='Karna', type='Person'), target=Node(id='Parasurama', type='Person'), type='DISCIPLE'), Relationship(source=Node(id='Parasurama', type='Person'), target=Node(id='Karna', type='Person'), type='GURU')]
# [Relationship(source=Node(id='Karna', type='Person'), target=Node(id='Duryodhana', type='Person'), type='FRIEND'), Relationship(source=Node(id='Karna', type='Person'), target=Node(id='Kauravas', type='Group'), type='MEMBER'), Relationship(source=Node(id='Karna', type='Person'), target=Node(id='Bhishma', type='Person'), type='FOUGHT_AGAINST'), Relationship(source=Node(id='Karna', type='Person'), target=Node(id='Drona', type='Person'), type='FOUGHT_AGAINST'), Relationship(source=Node(id='Arjuna', type='Person'), target=Node(id='Karna', type='Person'), type='KILLED'), Relationship(source=Node(id='Kunti', type='Person'), target=Node(id='Karna', type='Person'), type='MOTHER'), Relationship(source=Node(id='Drona', type='Person'), target=Node(id='Bharadwaja', type='Person'), type='SON'), Relationship(source=Node(id='Drona', type='Person'), target=Node(id='Drupada', type='Person'), type='TEACHER')]
# [Relationship(source=Node(id='Drup Ada', type='Person'), target=Node(id='Drona', type='Person'), type='FRIEND'), Relationship(source=Node(id='Drona', type='Person'), target=Node(id='Kripa', type='Person'), type='SIBLING_IN_LAW'), Relationship(source=Node(id='Drona', type='Person'), target=Node(id='Aswatthama', type='Person'), type='PARENT'), Relationship(source=Node(id='Drona', type='Person'), target=Node(id='Parasurama', type='Person'), type='STUDENT')]
# [Relationship(source=Node(id='Drupada', type='Person'), target=Node(id='Drona', type='Person'), type='TEACHER_STUDENT')]
# [Relationship(source=Node(id='Ona', type='Person'), target=Node(id='King', type='Person'), type='INSULTED'), Relationship(source=Node(id='Ona', type='Person'), target=Node(id='Kripacharya', type='Person'), type='RELATIVE'), Relationship(source=Node(id='Yudhishthira', type='Person'), target=Node(id='Brahmana', type='Person'), type='OBSERVED')]
# [Relationship(source=Node(id='Yudhishthira', type='Person'), target=Node(id='Drona', type='Person'), type='CHALLENGES')]
# [Relationship(source=Node(id='Bhishma', type='Person'), target=Node(id='Drona', type='Person'), type='KNEW'), Relationship(source=Node(id='Drona', type='Person'), target=Node(id='Pandavas', type='Group'), type='INSTRUCTED'), Relationship(source=Node(id='Drona', type='Person'), target=Node(id='Kauravas', type='Group'), type='INSTRUCTED'), Relationship(source=Node(id='Drona', type='Person'), target=Node(id='Karna', type='Person'), type='SENT'), Relationship(source=Node(id='Drona', type='Person'), target=Node(id='Duryodhana', type='Person'), type='SENT'), Relationship(source=Node(id='Drona', type='Person'), target=Node(id='Arjuna', type='Person'), type='SENT'), Relationship(source=Node(id='Arjuna', type='Person'), target=Node(id='Drupada', type='Person'), type='DEFEATED')]
# [Relationship(source=Node(id='Drupada', type='Person'), target=Node(id='Dhrishtadyumna', type='Person'), type='CHILD')]
# [Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Bhima', type='Person'), type='ENVY'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Arjuna', type='Person'), type='ENVY'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Karna', type='Person'), type='ALLY'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Sakuni', type='Person'), type='ALLY'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Pandavas', type='Group'), type='ENEMY'), Relationship(source=Node(id='Dhritarashtra', type='Person'), target=Node(id='Duryodhana', type='Person'), type='PARENT'), Relationship(source=Node(id='Vidura', type='Person'), target=Node(id='Pandavas', type='Group'), type='HELPER')]
# [Relationship(source=Node(id='People', type='Person'), target=Node(id='Yudhishthira', type='Person'), type='PRAISE'), Relationship(source=Node(id='People', type='Person'), target=Node(id='Dhritarashtra', type='Person'), type='DISRESPECT'), Relationship(source=Node(id='People', type='Person'), target=Node(id='Bhishma', type='Person'), type='DISRESPECT'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Dhritarashtra', type='Person'), type='COMPLAINS')]
# [Relationship(source=Node(id='Dhritarashtra', type='Person'), target=Node(id='Yudhishthira', type='Person'), type='BROTHER'), Relationship(source=Node(id='Pandu', type='Person'), target=Node(id='Yudhishthira', type='Person'), type='FATHER')]
# [Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Bhishma', type='Person'), type='RELATION'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Ashwatthama', type='Person'), type='RELATION'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Drona', type='Person'), type='RELATION'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Kripa', type='Person'), type='RELATION'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Vidura', type='Person'), type='RELATION'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Pandavas', type='Person'), type='RELATION'), Relationship(source=Node(id='Pandavas', type='Person'), target=Node(id='Pandu', type='Person'), type='RELATION'), Relationship(source=Node(id='Kanika', type='Person'), target=Node(id='Sakuni', type='Person'), type='RELATION')]
# [Relationship(source=Node(id='Sakuni', type='Person'), target=Node(id='Duryodhana', type='Person'), type='ADVISES'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Dhritarashtra', type='Person'), type='REPORTS_TO'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id="Pandus' Sons", type='Person'), type='ENEMY_OF')]
# [Relationship(source=Node(id='Dhritarashtra', type='Person'), target=Node(id='Pandavas', type='Person'), type='INVITED'), Relationship(source=Node(id='Pandavas', type='Person'), target=Node(id='Varanavata', type='City'), type='TRAVEL_TO')]
# [Relationship(source=Node(id='Bhishma', type='Person'), target=Node(id='Varanavata', type='Location'), type='WENT_TO'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Karna', type='Person'), type='PLOTTED_WITH'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Sakuni', type='Person'), type='PLOTTED_WITH'), Relationship(source=Node(id='Duryodhana', type='Person'), target=Node(id='Purochana', type='Person'), type='SENT_FOR'), Relationship(source=Node(id='Purochana', type='Person'), target=Node(id='Varanavata', type='Location'), type='WENT_TO'), Relationship(source=Node(id='Purochana', type='Person'), target=Node(id='Pandavas', type='Group'), type='BUILT_PALACE_FOR'), Relationship(source=Node(id='Pandavas', type='Group'), target=Node(id='Varanavata', type='Location'), type='PROCEEDED_TO'), Relationship(source=Node(id='Pandavas', type='Group'), target=Node(id='Palace', type='Building'), type='SETTLED_DOWN_IN')]
# [Relationship(source=Node(id='Kauravas', type='Person'), target=Node(id='Pandavas', type='Person'), type='ENEMY'), Relationship(source=Node(id='Vidura', type='Person'), target=Node(id='Yudhishthira', type='Person'), type='ADVISER')]
# [Relationship(source=Node(id='Yudhishthira', type='Person'), target=Node(id='Sivam', type='Building'), type='STAYS_IN'), Relationship(source=Node(id='Yudhishthira', type='Person'), target=Node(id='Vidura', type='Person'), type='RECEIVES_WARNING_FROM'), Relationship(source=Node(id='Yudhishthira', type='Person'), target=Node(id='Bhima', type='Person'), type='TALKS_TO'), Relationship(source=Node(id='Purochana', type='Person'), target=Node(id='Sivam', type='Building'), type='CONSTRUCTS')]
# [Relationship(source=Node(id='Vidura', type='Person'), target=Node(id='Miner', type='Person'), type='SENT'), Relationship(source=Node(id='Miner', type='Person'), target=Node(id='Yudhishthira', type='Person'), type='WARNED'), Relationship(source=Node(id='Yudhishthira', type='Person'), target=Node(id='Kuntidevi', type='Person'), type='COMMUNICATED'), Relationship(source=Node(id='Yudhishthira', type='Person'), target=Node(id='Duryodhana', type='Person'), type='IN_DANGER')]
# ...
# [Relationship(source=Node(id='Mandavya', type='Person'), target=Node(id='Dharma', type='Person'), type='CURSED'), Relationship(source=Node(id='Dharma', type='Person'), target=Node(id='Vidura', type='Person'), type='REINCARNATED_AS'), Relationship(source=Node(id='Ambalika', type='Person'), target=Node(id='Vyasa', type='Person'), type='OFFERED_TO'), Relationship(source=Node(id='Ambalika', type='Person'), target=Node(id='Vichitravirya', type='Person'), type='WIFE_OF'), Relationship(source=Node(id='Maricha', type='Person'), target=Node(id='Ravana', type='Person'), type='UNCLE_OF'), Relationship(source=Node(id='Maricha', type='Person'), target=Node(id='Sita', type='Person'), type='LURED'), Relationship(source=Node(id='Markandeya', type='Person'), target=Node(id='Yudhishthira', type='Person'), type='TOLD_A_STORY_TO'), Relationship(source=Node(id='Kausika', type='Person'), target=Node(id='Yudhishthira', type='Person'), type='SUBJECT_OF_THE_STORY'), Relationship(source=Node(id='Marutta', type='Person'), target=Node(id='Samvarta', type='Person'), type='SACRIFICE_PERFORMED_BY'), Relationship(source=Node(id='Samvarta', type='Person'), target=Node(id='Indra', type='Person'), type='DEFIED'), Relationship(source=Node(id='Samvarta', type='Person'), target=Node(id='Brihaspati', type='Person'), type='DEFIED'), Relationship(source=Node(id='Matali', type='Person'), target=Node(id='Arjuna', type='Person'), type='CHARIOT_DRIVER_OF'), Relationship(source=Node(id='Baladhi', type='Person'), target=Node(id='Medhavi', type='Person'), type='FATHER_OF')]
# [Relationship(source=Node(id='Vindhya', type='Mountain'), target=Node(id='Sun', type='Celestial_body'), type='OBSTRUCTS'), Relationship(source=Node(id='Vindhya', type='Mountain'), target=Node(id='Moon', type='Celestial_body'), type='OBSTRUCTS'), Relationship(source=Node(id='Vindhya', type='Mountain'), target=Node(id='Planets', type='Celestial_body'), type='OBSTRUCTS'), Relationship(source=Node(id='Agastya', type='Sage'), target=Node(id='Vindhya', type='Mountain'), type='REQUESTS'), Relationship(source=Node(id='Nahusha', type='King'), target=Node(id='In Dra', type='King'), type='KILLS'), Relationship(source=Node(id='Nahusha', type='King'), target=Node(id='God', type='Deity'), type='BECOMES'), Relationship(source=Node(id='Nala', type='King'), target=Node(id='Damayanti', type='Person'), type='MARRIES'), Relationship(source=Node(id='Nala', type='King'), target=Node(id='Nishadha', type='Kingdom'), type='RULES'), Relationship(source=Node(id='Nala', type='King'), target=Node(id='Game_Of_Dice', type='Event'), type='LOSES'), Relationship(source=Node(id='Nala', type='King'), target=Node(id='Damayanti', type='Person'), type='ABANDONS'), Relationship(source=Node(id='Nandini', type='Cow'), target=Node(id='Vasishtha', type='Sage'), type='BELONGS_TO'), Relationship(source=Node(id='Nara', type='Person'), target=Node(id='Arjuna', type='Person'), type='IS'), Relationship(source=Node(id='Nara', type='Person'), target=Node(id='Dhananjaya', type='Person'), type='IS'), Relationship(source=Node(id='Narada', type='Sage'), target=Node(id='Dhritarashtra', type='Person'), type='APPEARS_BEFORE'), Relationship(source=Node(id='Narada', type='Sage'), target=Node(id='Vidura', type='Person'), type='APPEARS_BEFORE'), Relationship(source=Node(id='Narada', type='Sage'), target=Node(id='Pandavas', type='Group'), type='PROPHECIES'), Relationship(source=Node(id='Pandavas', type='Group'), target=Node(id='Forest', type='Location'), type='GOES_TO'), Relationship(source=Node(id='Kauravas', type='Group'), target=Node(id='Narada', type='Sage'), type='EXTINCT')]
# [Relationship(source=Node(id='Nga', type='Place'), target=Node(id='Romapada', type='Person'), type='RULER_OF'), Relationship(source=Node(id='Romapada', type='Person'), target=Node(id='Nga', type='Place'), type='RULED_BY'), Relationship(source=Node(id='Rudra', type='Person'), target=Node(id='Rudra Dance', type='Event'), type='PERFORMS'), Relationship(source=Node(id='Rukma', type='Person'), target=Node(id='Vidarbha', type='Place'), type='HEIR_OF'), Relationship(source=Node(id='Rukma', type='Person'), target=Node(id='Balarama', type='Person'), type='DEFEATED_BY'), Relationship(source=Node(id='Rukma', type='Person'), target=Node(id='Krishna', type='Person'), type='DEFEATED_BY'), Relationship(source=Node(id='Rukma', type='Person'), target=Node(id='Bhojakata', type='Place'), type='ESTABLISHED_CITY'), Relationship(source=Node(id='Rukma', type='Person'), target=Node(id='Kundinapura', type='Place'), type='RULED_OVER'), Relationship(source=Node(id='Sachidevi', type='Person'), target=Node(id='Indra', type='Person'), type='SPOUSE_OF'), Relationship(source=Node(id='Sachidevi', type='Person'), target=Node(id='Indrani', type='Person'), type='ALTERNATE_NAME'), Relationship(source=Node(id='Nahusha', type='Person'), target=Node(id='Sachidevi', type='Person'), type='EVIL_EYE_ON'), Relationship(source=Node(id='Sahadeva', type='Person'), target=Node(id='Pandava', type='Group'), type='MEMBER_OF'), Relationship(source=Node(id='Sahadeva', type='Person'), target=Node(id='Krishna', type='Person'), type='OFFERED_HONORS_TO'), Relationship(source=Node(id='Saibya', type='Person'), target=Node(id='Pandava', type='Group'), type='FRIENDLY_TO'), Relationship(source=Node(id='Sairandhri', type='Person'), target=Node(id='Royal_Female_Apartments', type='Place'), type='EMPLOYED_IN'), Relationship(source=Node(id='Sakuni', type='Person'), target=Node(id='Kauravas', type='Group'), type='PLAYED_DICE_FOR'), Relationship(source=Node(id='Sakuni', type='Person'), target=Node(id='Pandavas', type='Group'), type='DEFEATED')]
# [Relationship(source=Node(id='Salva', type='Person'), target=Node(id='Sisupala', type='Person'), type='FRIEND'), Relationship(source=Node(id='Sisupala', type='Person'), target=Node(id='Dwaraka', type='Kingdom'), type='SIEGE'), Relationship(source=Node(id='Sisupala', type='Person'), target=Node(id='Sri Krishna', type='Person'), type='ENEMY'), Relationship(source=Node(id='Salya', type='Person'), target=Node(id='Madradesa', type='Kingdom'), type='RULER'), Relationship(source=Node(id='Salya', type='Person'), target=Node(id='Madri', type='Person'), type='SIBLING'), Relationship(source=Node(id='Salya', type='Person'), target=Node(id='Pandavas', type='Group'), type='UNCLE'), Relationship(source=Node(id='Salya', type='Person'), target=Node(id='Duryodhana', type='Person'), type='ALLY'), Relationship(source=Node(id='Samsaptaka', type='Group'), target=Node(id='Brihaspati', type='Person'), type='STUDENT'), Relationship(source=Node(id='Samvarta', type='Person'), target=Node(id='Brihaspati', type='Person'), type='BROTHER'), Relationship(source=Node(id='Samba', type='Person'), target=Node(id='Yadava', type='Group'), type='MEMBER'), Relationship(source=Node(id='Sanga', type='Person'), target=Node(id='Virata', type='Person'), type='SON')]
# [Relationship(source=Node(id='Sanjaya', type='Person'), target=Node(id='Dhritarashtra', type='Person'), type='NARRATES_TO')]
# [Relationship(source=Node(id='Satyaki', type='Person'), target=Node(id='Krishna', type='Person'), type='FRIEND'), Relationship(source=Node(id='Satyaki', type='Person'), target=Node(id='Pandavas', type='Group'), type='FRIEND'), Relationship(source=Node(id='Satyaki', type='Person'), target=Node(id='Duryodhana', type='Person'), type='ADVERSARY'), Relationship(source=Node(id='Satyavati', type='Person'), target=Node(id='Santanu', type='Person'), type='SPOUSE'), Relationship(source=Node(id='Savyasachin', type='Person'), target=Node(id='Arjuna', type='Person'), type='ALIAS'), Relationship(source=Node(id='Sikhandin', type='Person'), target=Node(id='Drupada', type='Person'), type='SON')]
# [Relationship(source=Node(id='Abhimanyu', type='Person'), target=Node(id='Sumitra', type='Person'), type='CHARIOTEER')]
# [Relationship(source=Node(id='Supratika', type='Person'), target=Node(id='Bhagadatta', type='Person'), type='OWNED_BY'), Relationship(source=Node(id='Susarma', type='Person'), target=Node(id='Trigarta', type='Location'), type='RULES'), Relationship(source=Node(id='Susarma', type='Person'), target=Node(id='Kauravas', type='Group'), type='SUPPORTS'), Relationship(source=Node(id='Kauravas', type='Group'), target=Node(id='Matsya', type='Location'), type='INVADES'), Relationship(source=Node(id='Matsya', type='Location'), target=Node(id='Virata', type='Person'), type='LOCATED_IN'), Relationship(source=Node(id='Sri Rama', type='Person'), target=Node(id='Ramachandra', type='Person'), type='SAME_AS'), Relationship(source=Node(id='Sri Rama', type='Person'), target=Node(id='Sri Rama', type='Person'), type='SAME_AS'), Relationship(source=Node(id='Hanumana', type='Person'), target=Node(id='Bhima', type='Person'), type='TELLS'), Relationship(source=Node(id='Sri Rama', type='Person'), target=Node(id='Ayodhya', type='Location'), type='RULES'), Relationship(source=Node(id='Sri Rama', type='Person'), target=Node(id='Ravana', type='Person'), type='KILLS'), Relationship(source=Node(id='Ravana', type='Person'), target=Node(id='Lanka', type='Location'), type='RULES'), Relationship(source=Node(id='Sri Rama', type='Person'), target=Node(id='Sita', type='Person'), type='MARRIED_TO'), Relationship(source=Node(id='Srinjayas', type='Group'), target=Node(id='Pan', type='Group'), type='SUPPORTS'), Relationship(source=Node(id='Srutayu', type='Person'), target=Node(id='Astutayu', type='Person'), type='BROTHER'), Relationship(source=Node(id='Srutayu', type='Person'), target=Node(id='Astutayu', type='Person'), type='ATTACKS'), Relationship(source=Node(id='Arjuna', type='Person'), target=Node(id='Srutayu', type='Person'), type='DEFEATED'), Relationship(source=Node(id='Arjuna', type='Person'), target=Node(id='Astutayu', type='Person'), type='DEFEATED'), Relationship(source=Node(id='Srutayudha', type='Person'), target=Node(id='Krishna', type='Person'), type='ATTACKS'), Relationship(source=Node(id='Srutayudha', type='Person'), target=Node(id='Krishna', type='Person'), type='KILLED_BY'), Relationship(source=Node(id='Parnasa', type='Person'), target=Node(id='Srutayudha', type='Person'), type='PARENT'), Relationship(source=Node(id='Varuna', type='Person'), target=Node(id='Parnasa', type='Person'), type='GIVES'), Relationship(source=Node(id='Swarga', type='Location'), target=Node(id='Indra', type='Person'), type='RULES')]
# [Relationship(source=Node(id='Vali', type='Person'), target=Node(id='Sugriva', type='Person'), type='BROTHER')]
# [Relationship(source=Node(id='Udeva', type='Person'), target=Node(id='Supreme Spirit', type='Person'), type='IS'), Relationship(source=Node(id='Vedavyasa', type='Person'), target=Node(id='Mahabharata', type='Book'), type='AUTHOR'), Relationship(source=Node(id='Vyasa', type='Person'), target=Node(id='Mahabharata', type='Book'), type='AUTHOR'), Relationship(source=Node(id='Vichitravirya', type='Person'), target=Node(id='Santanu', type='Person'), type='SON'), Relationship(source=Node(id='Vichitravirya', type='Person'), target=Node(id='Chitrangada', type='Person'), type='SUCCEEDED'), Relationship(source=Node(id='Vichitravirya', type='Person'), target=Node(id='Dhritarashtra', type='Person'), type='SON'), Relationship(source=Node(id='Vichitravirya', type='Person'), target=Node(id='Pandu', type='Person'), type='SON'), Relationship(source=Node(id='Vikarna', type='Person'), target=Node(id='Dhritarashtra', type='Person'), type='SON'), Relationship(source=Node(id='Vikarna', type='Person'), target=Node(id='Draupadi', type='Person'), type='DECLARED_ILLEGAL_STAKING_OF'), Relationship(source=Node(id='Vikarna', type='Person'), target=Node(id='Yudhishthira', type='Person'), type='DECLARED_SLAVE'), Relationship(source=Node(id='Vikarna', type='Person'), target=Node(id='Kauravas', type='Group'), type='DID_NOT_LEGALLY_WIN'), Relationship(source=Node(id='Vinda', type='Person'), target=Node(id='Anuvinda', type='Person'), type='BROTHER'), Relationship(source=Node(id='Vinda', type='Person'), target=Node(id='Avanti', type='Country'), type='KING_OF'), Relationship(source=Node(id='Anuvinda', type='Person'), target=Node(id='Avanti', type='Country'), type='KING_OF'), Relationship(source=Node(id='Vinda', type='Person'), target=Node(id='Kauravas', type='Group'), type='ALLY'), Relationship(source=Node(id='Anuvinda', type='Person'), target=Node(id='Kauravas', type='Group'), type='ALLY'), Relationship(source=Node(id='Vinda', type='Person'), target=Node(id='Yudhamanyu', type='Person'), type='DEFEATED_BY'), Relationship(source=Node(id='Anuvinda', type='Person'), target=Node(id='Yudhamanyu', type='Person'), type='DEFEATED_BY'), Relationship(source=Node(id='Virata', type='Person'), target=Node(id='Matsya', type='Country'), type='KING_OF'), Relationship(source=Node(id='Bhima', type='Person'), target=Node(id='Virata', type='Person'), type='SUGGESTED_COUNTRY_FOR_INCOGNITO'), Relationship(source=Node(id='Visoka', type='Person'), target=Node(id='Bhima', type='Person'), type='CHARIOTEER'), Relationship(source=Node(id='Twashta', type='Person'), target=Node(id='Visvarupa', type='Person'), type='FATHER'), Relationship(source=Node(id='Visvarupa', type='Person'), target=Node(id='Brihaspati', type='Person'), type='PRECEPTOR'), Relationship(source=Node(id='Brihaspati', type='Person'), target=Node(id='Indra', type='Person'), type='INSULTED'), Relationship(source=Node(id='Vivimsati', type='Person'), target=Node(id='Kauravas', type='Group'), type='MEMBER')]
# [Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Devayani', type='Person'), type='RESCUED'), Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Sarmishtha', type='Person'), type='MARRIED'), Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Devayani', type='Person'), type='MARRIED'), Relationship(source=Node(id='Yayati', type='Person'), target=Node(id='Sukracharya', type='Person'), type='CURSED'), Relationship(source=Node(id='Yudhamanyu', type='Person'), target=Node(id='Pandavas', type='Group'), type='SUPPORTED'), Relationship(source=Node(id='Satyaki', type='Person'), target=Node(id='Yuyudhana', type='Person'), type='ALTERNATE_NAME'), Relationship(source=Node(id='Yuyutsu', type='Person'), target=Node(id='Dhritarashtra', type='Person'), type='SON'), Relationship(source=Node(id='Yuyutsu', type='Person'), target=Node(id='Yudhishthira', type='Person'), type='DISAPPROVED'), Relationship(source=Node(id='Yuyutsu', type='Person'), target=Node(id='Abhimanyu', type='Person'), type='DISAPPROVED'), Relationship(source=Node(id='Yudhishthira', type='Person'), target=Node(id='Draupadi', type='Person'), type='LOST')]
